# %%
import os

from time import sleep
import config
import config_reg_tv

from config_search_funcs import get_subbrand_id_str
from reg_tv_ratings import get_reg_tv_reports
from create_dicts_tv_index import update_nat_tv_ad_dict

start_date = '2025-05-01' # если дата начала НЕ указана, то start_date = Сегодня минус 3 дня минус 17 дней
end_date = '2025-05-01' #- ВКЛЮЧИТЕЛЬНО / если дата окончания НЕ указана, то end_date = Сегодня минус 3 дня

start_date =  start_date if 'start_date' in globals() else ''
end_date = end_date if 'end_date' in globals() else ''

flag='first' #first / regular

print(f'База данных для записи: {config.db_name}')
# Out:
# Все ок. Подключились!
# Загрузка завершена успешно
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# База данных для записи: mediascope_x5

# %%
#### Если флаг first - создаем набор пустых таблиц-справочников / 
# забираем статистику / заполняем таблицы фактов и справочник nat_tv_ad_dict
# Если флаг regular - то грузим статистику и обновляем справочники
# если start_date(дата начала) НЕ указана, то 
# удаляем из БД - последние 17(сегодня-14-3) дней
# перезаисываем статистику за этот период
# если НЕ указана end_date(дата окончания) - ВКЛЮЧИТЕЛЬНО, то грузим данные до сегодня-3 дня
# получаем статистику по отчету Simple и Buying
get_reg_tv_reports(start_date=start_date, end_date=end_date, flag=flag)
# Out:
# Скрипт запущен 2025-05-30 08:28:50.434642
# Все ок. Подключились!
# Пустая таблица reg_tv_simple успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Пустая таблица reg_tv_buying успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Пустая таблица reg_tv_ad_dict успешно создана в БД mediascope_x5
# **************************************************
# Забираем из БД НЕ ОБНОВЛЕННЫЙ справочник объявлений
# Все ок. Подключились!
# Загрузка завершена успешно
# **************************************************
#
# Загружаем отчет за период 2025-05-01 - 2025-05-01. Общее количество дней: 1
# **************************************************
#
#
# ==========Загружаем 2025-05-01. Отправляем задания на расчет
#
# -------------------- Забираем статистику по отчету Buying -- Region_name: БАРНАУЛ --Дата  2025-05-01
# Порядковый номер региона 0 из 27
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Расчет задачи (id: 6fc24cef-d6f8-42e6-835c-27ad5b07a4e0) [= = = = = = = ] время расчета: 0:00:22.228295
# Все ок. Подключились!
# Загрузка завершена успешно
# Записываем данные в таблицу фактов Buying
#
# Все ок. Подключились!
# Скрипт запущен 2025-05-30 08:29:19.198826
# Данные добавлены в БД: mediascope_x5, таблица: reg_tv_buying
# Скрипт отработал 2025-05-30 08:29:19.356217
# Время выполнения задачи: 0:00:00.157391
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
#
# **************************************************
#
# -------------------- Забираем статистику по отчету Simple -- Region_name: БАРНАУЛ --Дата:  2025-05-01
# Порядковый номер региона 0 из 27
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
#
# Ждем выполнения
# Расчет задач (13) [ = = = ] время расчета: 0:00:17.940309
# Расчет завершен, получаем результат
# Собираем таблицу
# .............Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
#
# **************************************************
# Записываем данные в справочник объявлений REG TV Index
#
# Все ок. Подключились!
# Скрипт запущен 2025-05-30 08:30:16.299137
# Данные добавлены в БД: mediascope_x5, таблица: reg_tv_ad_dict
# Скрипт отработал 2025-05-30 08:30:16.332480
# Время выполнения задачи: 0:00:00.033343
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# **************************************************
#
# Записываем данные в таблицу фактов Simple
#
# Все ок. Подключились!
# Скрипт запущен 2025-05-30 08:30:16.348174
# Данные добавлены в БД: mediascope_x5, таблица: reg_tv_simple
# Скрипт отработал 2025-05-30 08:30:19.189902
# Время выполнения задачи: 0:00:02.841728
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# **************************************************
#
# -------------------- Забираем статистику по отчету Buying -- Region_name: ВЛАДИВОСТОК --Дата  2025-05-01
# Порядковый номер региона 1 из 27
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Расчет задачи (id: 292bf583-293a-40ab-bb2e-bb392bf4029d) [= = = = = = ] время расчета: 0:00:19.207345
# Все ок. Подключились!
# Загрузка завершена успешно
# Записываем данные в таблицу фактов Buying
#
# Все ок. Подключились!
# Скрипт запущен 2025-05-30 08:30:43.563972
# Данные добавлены в БД: mediascope_x5, таблица: reg_tv_buying
# Скрипт отработал 2025-05-30 08:30:43.680728
# Время выполнения задачи: 0:00:00.116756
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
#
# **************************************************
#
# -------------------- Забираем статистику по отчету Simple -- Region_name: ВЛАДИВОСТОК --Дата:  2025-05-01
# Порядковый номер региона 1 из 27
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
#
# Ждем выполнения
# Расчет задач (13) [ = = = ] время расчета: 0:00:17.903964
# Расчет завершен, получаем результат
# Собираем таблицу
# .............Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
#
# **************************************************
# Записываем данные в справочник объявлений REG TV Index
#
# Все ок. Подключились!
# Скрипт запущен 2025-05-30 08:31:39.533548
# Данные добавлены в БД: mediascope_x5, таблица: reg_tv_ad_dict
# Скрипт отработал 2025-05-30 08:31:39.564828
# Время выполнения задачи: 0:00:00.031280
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# **************************************************
#
# Записываем данные в таблицу фактов Simple
#
# Все ок. Подключились!
# Скрипт запущен 2025-05-30 08:31:39.588516
# Данные добавлены в БД: mediascope_x5, таблица: reg_tv_simple
# Скрипт отработал 2025-05-30 08:31:42.131904
# Время выполнения задачи: 0:00:02.543388
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# **************************************************
#
# -------------------- Забираем статистику по отчету Buying -- Region_name: ВОЛГОГРАД --Дата  2025-05-01
# Порядковый номер региона 2 из 27
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Расчет задачи (id: 113d7ba3-76e9-4988-9f19-1a6f53a25c06) [= = = = = = = ] время расчета: 0:00:22.237334
# Все ок. Подключились!
# Загрузка завершена успешно
# Записываем данные в таблицу фактов Buying
#
# Все ок. Подключились!
# Скрипт запущен 2025-05-30 08:32:11.093014
# Данные добавлены в БД: mediascope_x5, таблица: reg_tv_buying
# Скрипт отработал 2025-05-30 08:32:11.273589
# Время выполнения задачи: 0:00:00.180575
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
#
# **************************************************
#
# -------------------- Забираем статистику по отчету Simple -- Region_name: ВОЛГОГРАД --Дата:  2025-05-01
# Порядковый номер региона 2 из 27
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
#
# Ждем выполнения
# Расчет задач (13) [ = = ] время расчета: 0:00:11.961896
# Расчет завершен, получаем результат
# Собираем таблицу
# .............Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
#
# **************************************************
# Записываем данные в справочник объявлений REG TV Index
#
# Все ок. Подключились!
# Скрипт запущен 2025-05-30 08:33:02.415192
# Данные добавлены в БД: mediascope_x5, таблица: reg_tv_ad_dict
# Скрипт отработал 2025-05-30 08:33:02.446469
# Время выполнения задачи: 0:00:00.031277
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# **************************************************
#
# Записываем данные в таблицу фактов Simple
#
# Все ок. Подключились!
# Скрипт запущен 2025-05-30 08:33:02.462185
# Данные добавлены в БД: mediascope_x5, таблица: reg_tv_simple
# Скрипт отработал 2025-05-30 08:33:06.046826
# Время выполнения задачи: 0:00:03.584641
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# **************************************************
#
# -------------------- Забираем статистику по отчету Buying -- Region_name: ВОРОНЕЖ --Дата  2025-05-01
# Порядковый номер региона 3 из 27
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Расчет задачи (id:
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# **************************************************
#
# -------------------- Забираем статистику по отчету Buying -- Region_name: ТЮМЕНЬ --Дата  2025-05-01
# Порядковый номер региона 22 из 27
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Расчет задачи (id: 5ad9b8fc-d56a-4b6c-861f-a7c7074a1f10) [= = = = = ] время расчета: 0:00:16.165163
# Все ок. Подключились!
# Загрузка завершена успешно
# Записываем данные в таблицу фактов Buying
#
# Все ок. Подключились!
# Скрипт запущен 2025-05-30 09:03:19.637716
# Данные добавлены в БД: mediascope_x5, таблица: reg_tv_buying
# Скрипт отработал 2025-05-30 09:03:19.851717
# Время выполнения задачи: 0:00:00.214001
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
#
# **************************************************
#
# -------------------- Забираем статистику по отчету Simple -- Region_name: ТЮМЕНЬ --Дата:  2025-05-01
# Порядковый номер региона 22 из 27
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
#
# Ждем выполнения
# Расчет задач (13) [ = = = ] время расчета: 0:00:17.913441
# Расчет завершен, получаем результат
# Собираем таблицу
# .............Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
#
# **************************************************
# Записываем данные в справочник объявлений REG TV Index
#
# Все ок. Подключились!
# Скрипт запущен 2025-05-30 09:04:25.668328
# Данные добавлены в БД: mediascope_x5, таблица: reg_tv_ad_dict
# Скрипт отработал 2025-05-30 09:04:25.692062
# Время выполнения задачи: 0:00:00.023734
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# **************************************************
#
# Записываем данные в таблицу фактов Simple
#
# Все ок. Подключились!
# Скрипт запущен 2025-05-30 09:04:25.723194
# Данные добавлены в БД: mediascope_x5, таблица: reg_tv_simple
# Скрипт отработал 2025-05-30 09:04:29.660030
# Время выполнения задачи: 0:00:03.936836
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# **************************************************
#
# -------------------- Забираем статистику по отчету Buying -- Region_name: УФА --Дата  2025-05-01
# Порядковый номер региона 23 из 27
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Расчет задачи (id: 1cdd095e-2c48-4f91-b6ac-0ec808fdf346) [= = = = = = ] время расчета: 0:00:19.199974
# Все ок. Подключились!
# Загрузка завершена успешно
# Записываем данные в таблицу фактов Buying
#
# Все ок. Подключились!
# Скрипт запущен 2025-05-30 09:04:56.276015
# Данные добавлены в БД: mediascope_x5, таблица: reg_tv_buying
# Скрипт отработал 2025-05-30 09:04:56.548734
# Время выполнения задачи: 0:00:00.272719
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
#
# **************************************************
#
# -------------------- Забираем статистику по отчету Simple -- Region_name: УФА --Дата:  2025-05-01
# Порядковый номер региона 23 из 27
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
#
# Ждем выполнения
# Расчет задач (13) [ = = = ] время расчета: 0:00:17.914481
# Расчет завершен, получаем результат
# Собираем таблицу
# .............Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
#
# **************************************************
# Записываем данные в справочник объявлений REG TV Index
#
# Все ок. Подключились!
# Скрипт запущен 2025-05-30 09:06:03.637869
# Данные добавлены в БД: mediascope_x5, таблица: reg_tv_ad_dict
# Скрипт отработал 2025-05-30 09:06:03.656869
# Время выполнения задачи: 0:00:00.019000
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# **************************************************
#
# Записываем данные в таблицу фактов Simple
#
# Все ок. Подключились!
# Скрипт запущен 2025-05-30 09:06:03.682147
# Данные добавлены в БД: mediascope_x5, таблица: reg_tv_simple
# Скрипт отработал 2025-05-30 09:06:07.333029
# Время выполнения задачи: 0:00:03.650882
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# **************************************************
#
# -------------------- Забираем статистику по отчету Buying -- Region_name: ХАБАРОВСК --Дата  2025-05-01
# Порядковый номер региона 24 из 27
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Расчет задачи (id: e13c4e47-9b5b-4602-a0a0-f446540ca9ab) [= = = = = = = ] время расчета: 0:00:22.294158
# Все ок. Подключились!
# Загрузка завершена успешно
# Записываем данные в таблицу фактов Buying
#
# Все ок. Подключились!
# Скрипт запущен 2025-05-30 09:06:35.607398
# Данные добавлены в БД: mediascope_x5, таблица: reg_tv_buying
# Скрипт отработал 2025-05-30 09:06:35.722974
# Время выполнения задачи: 0:00:00.115576
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
#
# **************************************************
#
# -------------------- Забираем статистику по отчету Simple -- Region_name: ХАБАРОВСК --Дата:  2025-05-01
# Порядковый номер региона 24 из 27
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
#
# Ждем выполнения
# Расчет задач (13) [ = = = ] время расчета: 0:00:17.789422
# Расчет завершен, получаем результат
# Собираем таблицу
# .............Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
#
# **************************************************
# Записываем данные в справочник объявлений REG TV Index
#
# Все ок. Подключились!
# Скрипт запущен 2025-05-30 09:07:42.851955
# Данные добавлены в БД: mediascope_x5, таблица: reg_tv_ad_dict
# Скрипт отработал 2025-05-30 09:07:42.868788
# Время выполнения задачи: 0:00:00.016833
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# **************************************************
#
# Записываем данные в таблицу фактов Simple
#
# Все ок. Подключились!
# Скрипт запущен 2025-05-30 09:07:42.889595
# Данные добавлены в БД: mediascope_x5, таблица: reg_tv_simple
# Скрипт отработал 2025-05-30 09:07:44.896184
# Время выполнения задачи: 0:00:02.006589
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# **************************************************
#
# -------------------- Забираем статистику по отчету Buying -- Region_name: ЧЕЛЯБИНСК --Дата  2025-05-01
# Порядковый номер региона 25 из 27
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Расчет задачи (id: 4fa2b767-b3ae-407b-95cb-4774806d18f0) [= = = = = = ] время расчета: 0:00:19.155511
# Все ок. Подключились!
# Загрузка завершена успешно
# Записываем данные в таблицу фактов Buying
#
# Все ок. Подключились!
# Скрипт запущен 2025-05-30 09:08:10.776164
# Данные добавлены в БД: mediascope_x5, таблица: reg_tv_buying
# Скрипт отработал 2025-05-30 09:08:10.956023
# Время выполнения задачи: 0:00:00.179859
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
#
# **************************************************
#
# -------------------- Забираем статистику по отчету Simple -- Region_name: ЧЕЛЯБИНСК --Дата:  2025-05-01
# Порядковый номер региона 25 из 27
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
#
# Ждем выполнения
# Расчет задач (13) [ = = = ] время расчета: 0:00:17.820092
# Расчет завершен, получаем результат
# Собираем таблицу
# .............Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
#
# **************************************************
# Записываем данные в справочник объявлений REG TV Index
#
# Все ок. Подключились!
# Скрипт запущен 2025-05-30 09:09:22.701222
# Данные добавлены в БД: mediascope_x5, таблица: reg_tv_ad_dict
# Скрипт отработал 2025-05-30 09:09:22.726885
# Время выполнения задачи: 0:00:00.025663
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# **************************************************
#
# Записываем данные в таблицу фактов Simple
#
# Все ок. Подключились!
# Скрипт запущен 2025-05-30 09:09:22.754698
# Данные добавлены в БД: mediascope_x5, таблица: reg_tv_simple
# Скрипт отработал 2025-05-30 09:09:26.015147
# Время выполнения задачи: 0:00:03.260449
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# **************************************************
#
# -------------------- Забираем статистику по отчету Buying -- Region_name: ЯРОСЛАВЛЬ --Дата  2025-05-01
# Порядковый номер региона 26 из 27
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Расчет задачи (id: 9898068a-91c3-48f2-93c5-76efcd98dc4a) [= = = = = ] время расчета: 0:00:16.207751
# Все ок. Подключились!
# Загрузка завершена успешно
# Записываем данные в таблицу фактов Buying
#
# Все ок. Подключились!
# Скрипт запущен 2025-05-30 09:09:49.274328
# Данные добавлены в БД: mediascope_x5, таблица: reg_tv_buying
# Скрипт отработал 2025-05-30 09:09:49.418418
# Время выполнения задачи: 0:00:00.144090
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
#
# **************************************************
#
# -------------------- Забираем статистику по отчету Simple -- Region_name: ЯРОСЛАВЛЬ --Дата:  2025-05-01
# Порядковый номер региона 26 из 27
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
#
# Ждем выполнения
# Расчет задач (13) [ = = = = ] время расчета: 0:00:23.842511
# Расчет завершен, получаем результат
# Собираем таблицу
# .............Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
#
# **************************************************
# Записываем данные в справочник объявлений REG TV Index
#
# Все ок. Подключились!
# Скрипт запущен 2025-05-30 09:11:02.719476
# Данные добавлены в БД: mediascope_x5, таблица: reg_tv_ad_dict
# Скрипт отработал 2025-05-30 09:11:02.728618
# Время выполнения задачи: 0:00:00.009142
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# **************************************************
#
# Записываем данные в таблицу фактов Simple
#
# Все ок. Подключились!
# Скрипт запущен 2025-05-30 09:11:02.761660
# Данные добавлены в БД: mediascope_x5, таблица: reg_tv_simple
# Скрипт отработал 2025-05-30 09:11:05.789225
# Время выполнения задачи: 0:00:03.027565
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# **************************************************
#
# **************************************************
# Время окончания работы скрипта 2025-05-30 09:11:05.789225
# Период загрузки 2025-05-01 - 2025-05-01. Общее время работы скрипта: 0:42:15.354583
# **************************************************

# %%
update_nat_tv_ad_dict(tv_report='reg')
# Out:
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Таблица: reg_tv_ad_dict успешно удалена в БД: mediascope_x5
# ##########
# Все ок. Подключились!
# Пустая таблица reg_tv_ad_dict успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Скрипт запущен 2025-05-30 09:11:19.113054
# Данные добавлены в БД: mediascope_x5, таблица: reg_tv_ad_dict
# Скрипт отработал 2025-05-30 09:11:19.161463
# Время выполнения задачи: 0:00:00.048409
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
