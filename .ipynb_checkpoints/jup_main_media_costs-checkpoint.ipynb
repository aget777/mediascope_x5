# %%
import os

from time import sleep
import config
import config_media_costs
from config_search_funcs import get_subbrand_id_str
from media_costs import get_media_costs_report, get_mon_num_from_date, update_media_cost
from create_dicts_adex import create_adex_tables, download_adex_default_dicts, update_media_ads_dict, update_ad_dict_items, update_another_dicts, update_list_dicts, create_adex_views
from google_connector import append_ads_to_google, query_for_google


# subbrand_id_str = get_subbrand_id_str(mon_num='360')
# special_ad_filter = f'{config_media_costs.main_filter_str} AND t10.sbid in ({subbrand_id_str})'

start_date = '2025-02-01' # если дата начала НЕ указана, то start_date = Сегодня минус 3 дня минус 17 дней
end_date = '2025-02-02' #- ВКЛЮЧИТЕЛЬНО / если дата окончания НЕ указана, то end_date = Сегодня минус 3 дня

flag='first' #first / regular
# Out:
# Все ок. Подключились!
# Загрузка завершена успешно

# %%
# создаем пустые таблицы Фактов и Справочники
# Заполняем справоники по умолчанию данными config_media_costs.adex_defult_dicts
# Company / Ad_type / EState / 
if flag=='first':
    # создаем все пустые таблицы
    create_adex_tables()
    sleep(10)
    # наполняем данными справочники, которые НЕ обновляются
    download_adex_default_dicts()
    sleep(10)
    # создаем Представления
    create_adex_views()

# забираем статистику по каждому Медиа за указанный период
for key, value in config.media_type_dict.items():
    get_media_costs_report(start_date=start_date, end_date=end_date, media_type=key,  flag=flag)
# Out:
# Все ок. Подключились!
# Пустая таблица adex_distribution_dict успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Пустая таблица adex_estate_dict успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Пустая таблица adex_regions_dict успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Пустая таблица media_tv_costs успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Пустая таблица adex_company_dict_tv успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Пустая таблица adex_ad_type_dict_tv успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Пустая таблица adex_audio_slogan_dict_tv успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Пустая таблица adex_video_slogan_dict_tv успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Пустая таблица adex_ad_dict_list_tv успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Пустая таблица media_radio_costs успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Пустая таблица adex_company_dict_radio успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Пустая таблица adex_ad_type_dict_radio успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Пустая таблица adex_ad_dict_list_radio успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Пустая таблица media_press_costs успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Пустая таблица adex_company_dict_press успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Пустая таблица adex_ad_type_dict_press успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Пустая таблица adex_ad_dict_list_press успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Пустая таблица media_outdoor_costs успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Пустая таблица adex_company_dict_outdoor успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Пустая таблица adex_ad_type_dict_outdoor успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Пустая таблица adex_network_dict_outdoor успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Пустая таблица adex_ad_dict_list_outdoor успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Пустая таблица adex_advertiser_list_dict успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Пустая таблица adex_brand_list_dict успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Пустая таблица adex_subbrand_list_dict успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Пустая таблица adex_model_list_dict успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Пустая таблица adex_article_list2_dict успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Пустая таблица adex_article_list3_dict успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Пустая таблица adex_article_list4_dict успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-05-15 18:17:27.480208
# Данные добавлены в БД: mediascope_x5, таблица: adex_distribution_dict
# Скрипт отработал 2025-05-15 18:17:27.502387
# Время выполнения задачи: 0:00:00.022179
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-05-15 18:17:27.511396
# Данные добавлены в БД: mediascope_x5, таблица: adex_estate_dict
# Скрипт отработал 2025-05-15 18:17:27.525391
# Время выполнения задачи: 0:00:00.013995
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-05-15 18:17:27.533618
# Данные добавлены в БД: mediascope_x5, таблица: adex_regions_dict
# Скрипт отработал 2025-05-15 18:17:27.546621
# Время выполнения задачи: 0:00:00.013003
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-05-15 18:17:27.602564
# Данные добавлены в БД: mediascope_x5, таблица: adex_company_dict_tv
# Скрипт отработал 2025-05-15 18:17:27.682893
# Время выполнения задачи: 0:00:00.080329
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-05-15 18:17:27.694615
# Данные добавлены в БД: mediascope_x5, таблица: adex_ad_type_dict_tv
# Скрипт отработал 2025-05-15 18:17:27.718222
# Время выполнения задачи: 0:00:00.023607
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-05-15 18:17:27.738017
# Данные добавлены в БД: mediascope_x5, таблица: adex_company_dict_radio
# Скрипт отработал 2025-05-15 18:17:27.756135
# Время выполнения задачи: 0:00:00.018118
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-05-15 18:17:27.766135
# Данные добавлены в БД: mediascope_x5, таблица: adex_ad_type_dict_radio
# Скрипт отработал 2025-05-15 18:17:27.777134
# Время выполнения задачи: 0:00:00.010999
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-05-15 18:17:27.837690
# Данные добавлены в БД: mediascope_x5, таблица: adex_company_dict_outdoor
# Скрипт отработал 2025-05-15 18:17:28.032872
# Время выполнения задачи: 0:00:00.195182
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-05-15 18:17:28.045874
# Данные добавлены в БД: mediascope_x5, таблица: adex_ad_type_dict_outdoor
# Скрипт отработал 2025-05-15 18:17:28.062634
# Время выполнения задачи: 0:00:00.016760
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-05-15 18:17:28.082155
# Данные добавлены в БД: mediascope_x5, таблица: adex_network_dict_outdoor
# Скрипт отработал 2025-05-15 18:17:28.131497
# Время выполнения задачи: 0:00:00.049342
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-05-15 18:17:28.168522
# Данные добавлены в БД: mediascope_x5, таблица: adex_company_dict_press
# Скрипт отработал 2025-05-15 18:17:28.231544
# Время выполнения задачи: 0:00:00.063022
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-05-15 18:17:28.243545
# Данные добавлены в БД: mediascope_x5, таблица: adex_ad_type_dict_press
# Скрипт отработал 2025-05-15 18:17:28.255639
# Время выполнения задачи: 0:00:00.012094
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# Все ок. Подключились!
# Создано Представление media_ad_dict_view
# ##########
# Все ок. Подключились!
# Создано Представление all_reports_ad_dict_view
# ##########
# Все ок. Подключились!
# Создано Представление media_ad_type_dict_view
# ##########
# Все ок. Подключились!
# Создано Представление media_costs_union_view
# ##########
# Все ок. Подключились!
# Создано Представление media_company_dict_view
# ##########
# Все ок. Подключились!
# Создано Представление ad_type_view
# ##########
# Все ок. Подключились!
# Создано Представление regions_view
# ##########
# Все ок. Подключились!
# Создано Представление articleList2_view
# ##########
# Все ок. Подключились!
# Создано Представление articleList3_view
# ##########
# Все ок. Подключились!
# Создано Представление articleList4_view
# ##########
# Все ок. Подключились!
# Создано Представление advertiserList_view
# ##########
# Все ок. Подключились!
# Создано Представление brandList_view
# ##########
# Все ок. Подключились!
# Создано Представление subBrandList_view
# ##########
# Все ок. Подключились!
# Создано Представление modelList_view
# ##########
# Все ок. Подключились!
# Создано Представление tv_video_slogan_view
# ##########
# Все ок. Подключились!
# Создано Представление tv_audio_slogan_view
# ##########
# Все ок. Подключились!
# Создано Представление standardDuration_view
# ##########
# Все ок. Подключились!
# Создано Представление media_type_view
# ##########
# Все ок. Подключились!
# Создано Представление media_type_detail_view
# ##########
# Все ок. Подключились!
# Создано Представление tv_type_ooh_reg_view
# ##########
# Все ок. Подключились!
# Создано Представление google_cleaning_adex_view
# ##########
# Все ок. Подключились!
# Создано Представление google_cleaning_tv_index_view
# ##########
# Скрипт запущен 2025-05-15 18:17:38.337166
#
# Загружаем отчет за период 2025-02-01 - 2025-02-02. Общее количество месяцев: 1
# **************************************************
#
#
# ==========Загружаем 2025-02-01. Статистика по tv
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-05-15 18:17:43.890523
# Данные добавлены в БД: mediascope_x5, таблица: media_tv_costs
# Скрипт отработал 2025-05-15 18:17:45.309948
# Время выполнения задачи: 0:00:01.419425
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# Скрипт запущен 2025-05-15 18:17:45.318605
#
# Загружаем отчет за период 2025-02-01 - 2025-02-02. Общее количество месяцев: 1
# **************************************************
#
#
# ==========Загружаем 2025-02-01. Статистика по ra
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-05-15 18:17:47.760363
# Данные добавлены в БД: mediascope_x5, таблица: media_radio_costs
# Скрипт отработал 2025-05-15 18:17:47.859272
# Время выполнения задачи: 0:00:00.098909
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# Скрипт запущен 2025-05-15 18:17:47.860268
#
# Загружаем отчет за период 2025-02-01 - 2025-02-02. Общее количество месяцев: 1
# **************************************************
#
#
# ==========Загружаем 2025-02-01. Статистика по od
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-05-15 18:17:51.188266
# Данные добавлены в БД: mediascope_x5, таблица: media_outdoor_costs
# Скрипт отработал 2025-05-15 18:17:51.537828
# Время выполнения задачи: 0:00:00.349562
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# Скрипт запущен 2025-05-15 18:17:51.539829
#
# Загружаем отчет за период 2025-02-01 - 2025-02-02. Общее количество месяцев: 1
# **************************************************
#
#
# ==========Загружаем 2025-02-01. Статистика по pr
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-05-15 18:17:53.735267
# Данные добавлены в БД: mediascope_x5, таблица: media_press_costs
# Скрипт отработал 2025-05-15 18:17:53.758376
# Время выполнения задачи: 0:00:00.023109
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################

# %%
for media_type, media_type_long in config.media_type_dict.items():
    # здесь загружаем недостающие ИД
    update_media_ads_dict(media_type)
    # здесь обновляем кастомные поля(флаг чистки, категория и тд) в справочнике объявлений
    update_ad_dict_items(media_type)
    update_another_dicts(media_type)
    update_list_dicts(media_type)
# Out:
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-05-15 18:18:09.672596
# Данные добавлены в БД: mediascope_x5, таблица: adex_ad_dict_list_tv
# Скрипт отработал 2025-05-15 18:18:09.802539
# Время выполнения задачи: 0:00:00.129943
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-05-15 18:18:09.868864
# Данные добавлены в БД: mediascope_x5, таблица: adex_audio_slogan_dict_tv
# Скрипт отработал 2025-05-15 18:18:09.882971
# Время выполнения задачи: 0:00:00.014107
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-05-15 18:18:09.947587
# Данные добавлены в БД: mediascope_x5, таблица: adex_video_slogan_dict_tv
# Скрипт отработал 2025-05-15 18:18:09.959587
# Время выполнения задачи: 0:00:00.012000
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-05-15 18:18:10.016566
# Данные добавлены в БД: mediascope_x5, таблица: adex_advertiser_list_dict
# Скрипт отработал 2025-05-15 18:18:10.033321
# Время выполнения задачи: 0:00:00.016755
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-05-15 18:18:10.136196
# Данные добавлены в БД: mediascope_x5, таблица: adex_brand_list_dict
# Скрипт отработал 2025-05-15 18:18:10.160396
# Время выполнения задачи: 0:00:00.024200
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-05-15 18:18:10.250459
# Данные добавлены в БД: mediascope_x5, таблица: adex_subbrand_list_dict
# Скрипт отработал 2025-05-15 18:18:10.297321
# Время выполнения задачи: 0:00:00.046862
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-05-15 18:18:10.409396
# Данные добавлены в БД: mediascope_x5, таблица: adex_model_list_dict
# Скрипт отработал 2025-05-15 18:18:10.437467
# Время выполнения задачи: 0:00:00.028071
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-05-15 18:18:10.484408
# Данные добавлены в БД: mediascope_x5, таблица: adex_article_list2_dict
# Скрипт отработал 2025-05-15 18:18:10.508159
# Время выполнения задачи: 0:00:00.023751
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-05-15 18:18:10.590540
# Данные добавлены в БД: mediascope_x5, таблица: adex_article_list3_dict
# Скрипт отработал 2025-05-15 18:18:10.615988
# Время выполнения задачи: 0:00:00.025448
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-05-15 18:18:10.688076
# Данные добавлены в БД: mediascope_x5, таблица: adex_article_list4_dict
# Скрипт отработал 2025-05-15 18:18:10.719596
# Время выполнения задачи: 0:00:00.031520
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-05-15 18:18:35.349856
# Данные добавлены в БД: mediascope_x5, таблица: adex_ad_dict_list_radio
# Скрипт отработал 2025-05-15 18:18:35.375634
# Время выполнения задачи: 0:00:00.025778
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-05-15 18:18:35.444729
# Данные добавлены в БД: mediascope_x5, таблица: adex_advertiser_list_dict
# Скрипт отработал 2025-05-15 18:18:35.457317
# Время выполнения задачи: 0:00:00.012588
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-05-15 18:18:35.521470
# Данные добавлены в БД: mediascope_x5, таблица: adex_brand_list_dict
# Скрипт отработал 2025-05-15 18:18:35.535712
# Время выполнения задачи: 0:00:00.014242
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-05-15 18:18:35.592678
# Данные добавлены в БД: mediascope_x5, таблица: adex_subbrand_list_dict
# Скрипт отработал 2025-05-15 18:18:35.604919
# Время выполнения задачи: 0:00:00.012241
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-05-15 18:18:35.656857
# Данные добавлены в БД: mediascope_x5, таблица: adex_model_list_dict
# Скрипт отработал 2025-05-15 18:18:35.668858
# Время выполнения задачи: 0:00:00.012001
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-05-15 18:18:35.709180
# Данные добавлены в БД: mediascope_x5, таблица: adex_article_list2_dict
# Скрипт отработал 2025-05-15 18:18:35.719105
# Время выполнения задачи: 0:00:00.009925
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-05-15 18:18:35.764019
# Данные добавлены в БД: mediascope_x5, таблица: adex_article_list3_dict
# Скрипт отработал 2025-05-15 18:18:35.775019
# Время выполнения задачи: 0:00:00.011000
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-05-15 18:18:35.826186
# Данные добавлены в БД: mediascope_x5, таблица: adex_article_list4_dict
# Скрипт отработал 2025-05-15 18:18:35.837185
# Время выполнения задачи: 0:00:00.010999
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-05-15 18:18:43.814287
# Данные добавлены в БД: mediascope_x5, таблица: adex_ad_dict_list_outdoor
# Скрипт отработал 2025-05-15 18:18:43.890853
# Время выполнения задачи: 0:00:00.076566
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-05-15 18:18:43.965465
# Данные добавлены в БД: mediascope_x5, таблица: adex_advertiser_list_dict
# Скрипт отработал 2025-05-15 18:18:43.979982
# Время выполнения задачи: 0:00:00.014517
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-05-15 18:18:44.047262
# Данные добавлены в БД: mediascope_x5, таблица: adex_brand_list_dict
# Скрипт отработал 2025-05-15 18:18:44.066642
# Время выполнения задачи: 0:00:00.019380
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-05-15 18:18:44.136304
# Данные добавлены в БД: mediascope_x5, таблица: adex_subbrand_list_dict
# Скрипт отработал 2025-05-15 18:18:44.167597
# Время выполнения задачи: 0:00:00.031293
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-05-15 18:18:44.243130
# Данные добавлены в БД: mediascope_x5, таблица: adex_model_list_dict
# Скрипт отработал 2025-05-15 18:18:44.290926
# Время выполнения задачи: 0:00:00.047796
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-05-15 18:18:44.379708
# Данные добавлены в БД: mediascope_x5, таблица: adex_article_list2_dict
# Скрипт отработал 2025-05-15 18:18:44.391124
# Время выполнения задачи: 0:00:00.011416
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-05-15 18:18:44.465041
# Данные добавлены в БД: mediascope_x5, таблица: adex_article_list3_dict
# Скрипт отработал 2025-05-15 18:18:44.492923
# Время выполнения задачи: 0:00:00.027882
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-05-15 18:18:44.561723
# Данные добавлены в БД: mediascope_x5, таблица: adex_article_list4_dict
# Скрипт отработал 2025-05-15 18:18:44.577814
# Время выполнения задачи: 0:00:00.016091
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-05-15 18:19:00.424793
# Данные добавлены в БД: mediascope_x5, таблица: adex_ad_dict_list_press
# Скрипт отработал 2025-05-15 18:19:00.471755
# Время выполнения задачи: 0:00:00.046962
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-05-15 18:19:00.525224
# Данные добавлены в БД: mediascope_x5, таблица: adex_advertiser_list_dict
# Скрипт отработал 2025-05-15 18:19:00.534821
# Время выполнения задачи: 0:00:00.009597
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-05-15 18:19:00.597355
# Данные добавлены в БД: mediascope_x5, таблица: adex_brand_list_dict
# Скрипт отработал 2025-05-15 18:19:00.597355
# Время выполнения задачи: 0:00:00
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-05-15 18:19:00.660417
# Данные добавлены в БД: mediascope_x5, таблица: adex_subbrand_list_dict
# Скрипт отработал 2025-05-15 18:19:00.676042
# Время выполнения задачи: 0:00:00.015625
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-05-15 18:19:00.723443
# Данные добавлены в БД: mediascope_x5, таблица: adex_model_list_dict
# Скрипт отработал 2025-05-15 18:19:00.761521
# Время выполнения задачи: 0:00:00.038078
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-05-15 18:19:00.802146
# Данные добавлены в БД: mediascope_x5, таблица: adex_article_list2_dict
# Скрипт отработал 2025-05-15 18:19:00.818904
# Время выполнения задачи: 0:00:00.016758
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-05-15 18:19:00.865198
# Данные добавлены в БД: mediascope_x5, таблица: adex_article_list3_dict
# Скрипт отработал 2025-05-15 18:19:00.865198
# Время выполнения задачи: 0:00:00
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-05-15 18:19:00.928539
# Данные добавлены в БД: mediascope_x5, таблица: adex_article_list4_dict
# Скрипт отработал 2025-05-15 18:19:00.944181
# Время выполнения задачи: 0:00:00.015642
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################

# %%
# загружаем в гугл докс Чистка список объяалений с флагом=2
query = query_for_google(report='media')
worksheet = config_media_costs.google_new_ads_media_invest['worksheet']

append_ads_to_google(query=query, worksheet=worksheet)
# Out:
# Все ок. Подключились!
# Загрузка завершена успешно
# Connection established successfully...
# DataFrame exported successfully...

# %%
# # Может возникнуть необходимость перезаписать кастомные поля в таблицах расходов
# # например - пересмотрели размер дисконта / изменили правила опеределения одной из кастомных колонок и тд.
# # В этом случае забираем из нашей БД из каждой таблицы расходов колонки, которые мы взяли из Медиаскопа
# # И пропускаем по тем же шагам обработки, которые применялись в первоначальной загрузке
# # По итогу - удаляем существующую таблицу в БД и на ее место записываем таблицу с новуми данными
# for media_type in config.media_type_dict.keys():
#     update_media_cost(media_type)
