# %%
import os

from time import sleep
import config
import config_media_costs
from config_search_funcs import get_subbrand_id_str
from media_costs import get_media_costs_report, get_mon_num_from_date, update_media_cost
from create_dicts_adex import create_adex_tables, download_adex_default_dicts, update_media_ads_dict, update_ad_dict_items, update_another_dicts, update_list_dicts, create_adex_views

from create_dicts_tv_index import update_tv_index_dicts, update_nat_tv_ad_dict

from google_connector import append_ads_to_google, query_for_google


# subbrand_id_str = get_subbrand_id_str(mon_num='360')
# special_ad_filter = f'{config_media_costs.main_filter_str} AND t10.sbid in ({subbrand_id_str})'

# если дата начала НЕ указана, то start_date = 
# для Медиаинвестиций Сегодня минус 2 месяца 
# для Ретингов Сегодня минус 3 дня минус 17 дней
start_date = '2023-01-01' 

# ВКЛЮЧИТЕЛЬНО / 
# для Медиаинвестиций Сегодня минус 1 месяц
# для Ретингов если дата окончания НЕ указана, то end_date = Сегодня минус 3 дня

end_date = '2025-04-02' # ВКЛЮЧИТЕЛЬНО

start_date =  start_date if 'start_date' in globals() else ''
end_date = end_date if 'end_date' in globals() else ''

flag='first' #first / regular
# Out:
# Все ок. Подключились!
# Загрузка завершена успешно
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314

# %%
# создаем пустые таблицы Фактов и Справочники
# Заполняем справоники по умолчанию данными config_media_costs.adex_defult_dicts
# Company / Ad_type / EState / 
if flag=='first':
    # создаем все пустые таблицы
    create_adex_tables()
    sleep(10)
    # наполняем данными справочники, которые НЕ обновляются
    download_adex_default_dicts()
    sleep(10)
    # создаем Представления
    create_adex_views()
# Out:
# Все ок. Подключились!
# Пустая таблица adex_distribution_dict успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Пустая таблица adex_estate_dict успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Пустая таблица adex_regions_dict успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Пустая таблица media_tv_costs успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Пустая таблица adex_company_dict_tv успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Пустая таблица adex_ad_type_dict_tv успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Пустая таблица adex_audio_slogan_dict_tv успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Пустая таблица adex_video_slogan_dict_tv успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Пустая таблица adex_ad_dict_list_tv успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Пустая таблица media_radio_costs успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Пустая таблица adex_company_dict_radio успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Пустая таблица adex_ad_type_dict_radio успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Пустая таблица adex_ad_dict_list_radio успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Пустая таблица media_press_costs успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Пустая таблица adex_company_dict_press успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Пустая таблица adex_ad_type_dict_press успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Пустая таблица adex_ad_dict_list_press успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Пустая таблица media_outdoor_costs успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Пустая таблица adex_company_dict_outdoor успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Пустая таблица adex_ad_type_dict_outdoor успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Пустая таблица adex_network_dict_outdoor успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Пустая таблица adex_ad_dict_list_outdoor успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Пустая таблица adex_advertiser_list_dict успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Пустая таблица adex_brand_list_dict успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Пустая таблица adex_subbrand_list_dict успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Пустая таблица adex_model_list_dict успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Пустая таблица adex_article_list2_dict успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Пустая таблица adex_article_list3_dict успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Пустая таблица adex_article_list4_dict успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Таблица: adex_distribution_dict успешно удалена в БД: mediascope_x5
# ##########
# Все ок. Подключились!
# Пустая таблица adex_distribution_dict успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Скрипт запущен 2025-06-10 19:22:57.488962
# Данные добавлены в БД: mediascope_x5, таблица: adex_distribution_dict
# Скрипт отработал 2025-06-10 19:22:57.504610
# Время выполнения задачи: 0:00:00.015648
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Таблица: adex_estate_dict успешно удалена в БД: mediascope_x5
# ##########
# Все ок. Подключились!
# Пустая таблица adex_estate_dict успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Скрипт запущен 2025-06-10 19:22:57.535949
# Данные добавлены в БД: mediascope_x5, таблица: adex_estate_dict
# Скрипт отработал 2025-06-10 19:22:57.551668
# Время выполнения задачи: 0:00:00.015719
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Таблица: adex_regions_dict успешно удалена в БД: mediascope_x5
# ##########
# Все ок. Подключились!
# Пустая таблица adex_regions_dict успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Скрипт запущен 2025-06-10 19:22:57.572304
# Данные добавлены в БД: mediascope_x5, таблица: adex_regions_dict
# Скрипт отработал 2025-06-10 19:22:57.583969
# Время выполнения задачи: 0:00:00.011665
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Таблица: adex_company_dict_tv успешно удалена в БД: mediascope_x5
# ##########
# Все ок. Подключились!
# Пустая таблица adex_company_dict_tv успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Скрипт запущен 2025-06-10 19:22:57.646857
# Данные добавлены в БД: mediascope_x5, таблица: adex_company_dict_tv
# Скрипт отработал 2025-06-10 19:22:57.733590
# Время выполнения задачи: 0:00:00.086733
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Таблица: adex_ad_type_dict_tv успешно удалена в БД: mediascope_x5
# ##########
# Все ок. Подключились!
# Пустая таблица adex_ad_type_dict_tv успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Скрипт запущен 2025-06-10 19:22:57.754091
# Данные добавлены в БД: mediascope_x5, таблица: adex_ad_type_dict_tv
# Скрипт отработал 2025-06-10 19:22:57.769021
# Время выполнения задачи: 0:00:00.014930
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Таблица: adex_company_dict_radio успешно удалена в БД: mediascope_x5
# ##########
# Все ок. Подключились!
# Пустая таблица adex_company_dict_radio успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Скрипт запущен 2025-06-10 19:22:57.792022
# Данные добавлены в БД: mediascope_x5, таблица: adex_company_dict_radio
# Скрипт отработал 2025-06-10 19:22:57.815423
# Время выполнения задачи: 0:00:00.023401
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Таблица: adex_ad_type_dict_radio успешно удалена в БД: mediascope_x5
# ##########
# Все ок. Подключились!
# Пустая таблица adex_ad_type_dict_radio успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Скрипт запущен 2025-06-10 19:22:57.829377
# Данные добавлены в БД: mediascope_x5, таблица: adex_ad_type_dict_radio
# Скрипт отработал 2025-06-10 19:22:57.845022
# Время выполнения задачи: 0:00:00.015645
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Таблица: adex_company_dict_outdoor успешно удалена в БД: mediascope_x5
# ##########
# Все ок. Подключились!
# Пустая таблица adex_company_dict_outdoor успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Скрипт запущен 2025-06-10 19:22:57.921021
# Данные добавлены в БД: mediascope_x5, таблица: adex_company_dict_outdoor
# Скрипт отработал 2025-06-10 19:22:58.110542
# Время выполнения задачи: 0:00:00.189521
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Таблица: adex_ad_type_dict_outdoor успешно удалена в БД: mediascope_x5
# ##########
# Все ок. Подключились!
# Пустая таблица adex_ad_type_dict_outdoor успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Скрипт запущен 2025-06-10 19:22:58.140475
# Данные добавлены в БД: mediascope_x5, таблица: adex_ad_type_dict_outdoor
# Скрипт отработал 2025-06-10 19:22:58.154654
# Время выполнения задачи: 0:00:00.014179
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Таблица: adex_network_dict_outdoor успешно удалена в БД: mediascope_x5
# ##########
# Все ок. Подключились!
# Пустая таблица adex_network_dict_outdoor успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Скрипт запущен 2025-06-10 19:22:58.186107
# Данные добавлены в БД: mediascope_x5, таблица: adex_network_dict_outdoor
# Скрипт отработал 2025-06-10 19:22:58.235077
# Время выполнения задачи: 0:00:00.048970
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Таблица: adex_company_dict_press успешно удалена в БД: mediascope_x5
# ##########
# Все ок. Подключились!
# Пустая таблица adex_company_dict_press успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Скрипт запущен 2025-06-10 19:22:58.282193
# Данные добавлены в БД: mediascope_x5, таблица: adex_company_dict_press
# Скрипт отработал 2025-06-10 19:22:58.360319
# Время выполнения задачи: 0:00:00.078126
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Таблица: adex_ad_type_dict_press успешно удалена в БД: mediascope_x5
# ##########
# Все ок. Подключились!
# Пустая таблица adex_ad_type_dict_press успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Скрипт запущен 2025-06-10 19:22:58.385640
# Данные добавлены в БД: mediascope_x5, таблица: adex_ad_type_dict_press
# Скрипт отработал 2025-06-10 19:22:58.396914
# Время выполнения задачи: 0:00:00.011274
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# Все ок. Подключились!
# Ошибка при создании Представления media_ad_dict
# Все ок. Подключились!
# Ошибка при создании Представления all_reports_ad_dict
# Все ок. Подключились!
# Ошибка при создании Представления media_ad_type_dict
# Все ок. Подключились!
# Ошибка при создании Представления media_costs_union
# Все ок. Подключились!
# Ошибка при создании Представления media_company_dict
# Все ок. Подключились!
# Ошибка при создании Представления ad_type
# Все ок. Подключились!
# Ошибка при создании Представления regions
# Все ок. Подключились!
# Ошибка при создании Представления articleList2
# Все ок. Подключились!
# Ошибка при создании Представления articleList3
# Все ок. Подключились!
# Ошибка при создании Представления articleList4
# Все ок. Подключились!
# Ошибка при создании Представления advertiserList
# Все ок. Подключились!
# Ошибка при создании Представления brandList
# Все ок. Подключились!
# Ошибка при создании Представления subBrandList
# Все ок. Подключились!
# Ошибка при создании Представления modelList
# Все ок. Подключились!
# Ошибка при создании Представления tv_video_slogan
# Все ок. Подключились!
# Ошибка при создании Представления tv_audio_slogan
# Все ок. Подключились!
# Ошибка при создании Представления standardDuration
# Все ок. Подключились!
# Ошибка при создании Представления media_type
# Все ок. Подключились!
# Ошибка при создании Представления media_type_detail
# Все ок. Подключились!
# Ошибка при создании Представления tv_type_ooh_reg
# Все ок. Подключились!
# Ошибка при создании Представления google_cleaning_adex
# Все ок. Подключились!
# Ошибка при создании Представления google_cleaning_tv_index

# %%
# забираем статистику по каждому Медиа за указанный период
for key, value in config.media_type_dict.items():
    get_media_costs_report(start_date=start_date, end_date=end_date, media_type=key,  flag=flag)
# Out:
# Скрипт запущен 2025-06-10 19:23:08.495265
#
# Загружаем отчет за период 2023-01-01 - 2025-04-02. Общее количество месяцев: 28
# **************************************************
#
#
# ==========Загружаем 2023-01-01. Статистика по tv
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-06-10 19:23:27.897867
# Данные добавлены в БД: mediascope_x5, таблица: media_tv_costs
# Скрипт отработал 2025-06-10 19:23:28.874401
# Время выполнения задачи: 0:00:00.976534
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
#
# ==========Загружаем 2023-02-01. Статистика по tv
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-06-10 19:23:32.696621
# Данные добавлены в БД: mediascope_x5, таблица: media_tv_costs
# Скрипт отработал 2025-06-10 19:23:33.830791
# Время выполнения задачи: 0:00:01.134170
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
#
# ==========Загружаем 2023-03-01. Статистика по tv
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-06-10 19:23:37.914369
# Данные добавлены в БД: mediascope_x5, таблица: media_tv_costs
# Скрипт отработал 2025-06-10 19:23:39.076967
# Время выполнения задачи: 0:00:01.162598
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
#
# ==========Загружаем 2023-04-01. Статистика по tv
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-06-10 19:23:44.299313
# Данные добавлены в БД: mediascope_x5, таблица: media_tv_costs
# Скрипт отработал 2025-06-10 19:23:45.461852
# Время выполнения задачи: 0:00:01.162539
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
#
# ==========Загружаем 2023-05-01. Статистика по tv
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-06-10 19
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
#
# ==========Загружаем 2024-08-01. Статистика по pr
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-06-10 19:28:29.460457
# Данные добавлены в БД: mediascope_x5, таблица: media_press_costs
# Скрипт отработал 2025-06-10 19:28:29.477981
# Время выполнения задачи: 0:00:00.017524
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
#
# ==========Загружаем 2024-09-01. Статистика по pr
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-06-10 19:28:30.265813
# Данные добавлены в БД: mediascope_x5, таблица: media_press_costs
# Скрипт отработал 2025-06-10 19:28:30.297061
# Время выполнения задачи: 0:00:00.031248
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
#
# ==========Загружаем 2024-10-01. Статистика по pr
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-06-10 19:28:32.486960
# Данные добавлены в БД: mediascope_x5, таблица: media_press_costs
# Скрипт отработал 2025-06-10 19:28:32.518618
# Время выполнения задачи: 0:00:00.031658
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
#
# ==========Загружаем 2024-11-01. Статистика по pr
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-06-10 19:28:34.093584
# Данные добавлены в БД: mediascope_x5, таблица: media_press_costs
# Скрипт отработал 2025-06-10 19:28:34.109133
# Время выполнения задачи: 0:00:00.015549
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
#
# ==========Загружаем 2024-12-01. Статистика по pr
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-06-10 19:28:34.971649
# Данные добавлены в БД: mediascope_x5, таблица: media_press_costs
# Скрипт отработал 2025-06-10 19:28:34.984725
# Время выполнения задачи: 0:00:00.013076
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
#
# ==========Загружаем 2025-01-01. Статистика по pr
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-06-10 19:28:36.423107
# Данные добавлены в БД: mediascope_x5, таблица: media_press_costs
# Скрипт отработал 2025-06-10 19:28:36.454381
# Время выполнения задачи: 0:00:00.031274
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
#
# ==========Загружаем 2025-02-01. Статистика по pr
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-06-10 19:28:37.204958
# Данные добавлены в БД: mediascope_x5, таблица: media_press_costs
# Скрипт отработал 2025-06-10 19:28:37.231101
# Время выполнения задачи: 0:00:00.026143
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
#
# ==========Загружаем 2025-03-01. Статистика по pr
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-06-10 19:28:38.690077
# Данные добавлены в БД: mediascope_x5, таблица: media_press_costs
# Скрипт отработал 2025-06-10 19:28:38.705799
# Время выполнения задачи: 0:00:00.015722
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
#
# ==========Загружаем 2025-04-01. Статистика по pr
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-06-10 19:28:40.329297
# Данные добавлены в БД: mediascope_x5, таблица: media_press_costs
# Скрипт отработал 2025-06-10 19:28:40.347868
# Время выполнения задачи: 0:00:00.018571
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################

# %%
for media_type, media_type_long in config.media_type_dict.items():
    # здесь загружаем недостающие ИД
    update_media_ads_dict(media_type)
    # здесь обновляем кастомные поля(флаг чистки, категория и тд) в справочнике объявлений
    update_ad_dict_items(media_type)
    update_another_dicts(media_type)
    update_list_dicts(media_type)
# Out:
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# **************************************************
# Новых ИД НЕТ для загрузки в таблицу adex_ad_dict_list_tv
# **************************************************
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Таблица: adex_ad_dict_list_tv успешно удалена в БД: mediascope_x5
# ##########
# Все ок. Подключились!
# Пустая таблица adex_ad_dict_list_tv успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Скрипт запущен 2025-06-10 19:29:00.816092
# Данные добавлены в БД: mediascope_x5, таблица: adex_ad_dict_list_tv
# Скрипт отработал 2025-06-10 19:29:03.243476
# Время выполнения задачи: 0:00:02.427384
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# **************************************************
# Новых ИД НЕТ для загрузки в таблицу adex_audio_slogan_dict_tv
# **************************************************
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# **************************************************
# Новых ИД НЕТ для загрузки в таблицу adex_video_slogan_dict_tv
# **************************************************
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# **************************************************
# Новых ИД НЕТ для загрузки в таблицу adex_advertiser_list_dict
# **************************************************
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# **************************************************
# Новых ИД НЕТ для загрузки в таблицу adex_brand_list_dict
# **************************************************
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# **************************************************
# Новых ИД НЕТ для загрузки в таблицу adex_subbrand_list_dict
# **************************************************
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# **************************************************
# Новых ИД НЕТ для загрузки в таблицу adex_model_list_dict
# **************************************************
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# **************************************************
# Новых ИД НЕТ для загрузки в таблицу adex_article_list2_dict
# **************************************************
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# **************************************************
# Новых ИД НЕТ для загрузки в таблицу adex_article_list3_dict
# **************************************************
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# **************************************************
# Новых ИД НЕТ для загрузки в таблицу adex_article_list4_dict
# **************************************************
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# **************************************************
# Новых ИД НЕТ для загрузки в таблицу adex_ad_dict_list_radio
# **************************************************
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Таблица: adex_ad_dict_list_radio успешно удалена в БД: mediascope_x5
# ##########
# Все ок. Подключились!
# Пустая таблица adex_ad_dict_list_radio успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Скрипт запущен 2025-06-10 19:29:14.864199
# Данные добавлены в БД: mediascope_x5, таблица: adex_ad_dict_list_radio
# Скрипт отработал 2025-06-10 19:29:15.178164
# Время выполнения задачи: 0:00:00.313965
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# **************************************************
# Новых ИД НЕТ для загрузки в таблицу adex_advertiser_list_dict
# **************************************************
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# **************************************************
# Новых ИД НЕТ для загрузки в таблицу adex_brand_list_dict
# **************************************************
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# **************************************************
# Новых ИД НЕТ для загрузки в таблицу adex_subbrand_list_dict
# **************************************************
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# **************************************************
# Новых ИД НЕТ для загрузки в таблицу adex_model_list_dict
# **************************************************
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# **************************************************
# Новых ИД НЕТ для загрузки в таблицу adex_article_list2_dict
# **************************************************
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# **************************************************
# Новых ИД НЕТ для загрузки в таблицу adex_article_list3_dict
# **************************************************
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# **************************************************
# Новых ИД НЕТ для загрузки в таблицу adex_article_list4_dict
# **************************************************
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# **************************************************
# Новых ИД НЕТ для загрузки в таблицу adex_ad_dict_list_outdoor
# **************************************************
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Таблица: adex_ad_dict_list_outdoor успешно удалена в БД: mediascope_x5
# ##########
# Все ок. Подключились!
# Пустая таблица adex_ad_dict_list_outdoor успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Скрипт запущен 2025-06-10 19:29:31.915672
# Данные добавлены в БД: mediascope_x5, таблица: adex_ad_dict_list_outdoor
# Скрипт отработал 2025-06-10 19:29:32.751166
# Время выполнения задачи: 0:00:00.835494
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# **************************************************
# Новых ИД НЕТ для загрузки в таблицу adex_advertiser_list_dict
# **************************************************
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# **************************************************
# Новых ИД НЕТ для загрузки в таблицу adex_brand_list_dict
# **************************************************
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# **************************************************
# Новых ИД НЕТ для загрузки в таблицу adex_subbrand_list_dict
# **************************************************
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# **************************************************
# Новых ИД НЕТ для загрузки в таблицу adex_model_list_dict
# **************************************************
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# **************************************************
# Новых ИД НЕТ для загрузки в таблицу adex_article_list2_dict
# **************************************************
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# **************************************************
# Новых ИД НЕТ для загрузки в таблицу adex_article_list3_dict
# **************************************************
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# **************************************************
# Новых ИД НЕТ для загрузки в таблицу adex_article_list4_dict
# **************************************************
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# **************************************************
# Новых ИД НЕТ для загрузки в таблицу adex_ad_dict_list_press
# **************************************************
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Таблица: adex_ad_dict_list_press успешно удалена в БД: mediascope_x5
# ##########
# Все ок. Подключились!
# Пустая таблица adex_ad_dict_list_press успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Скрипт запущен 2025-06-10 19:29:43.705311
# Данные добавлены в БД: mediascope_x5, таблица: adex_ad_dict_list_press
# Скрипт отработал 2025-06-10 19:29:43.736584
# Время выполнения задачи: 0:00:00.031273
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# **************************************************
# Новых ИД НЕТ для загрузки в таблицу adex_advertiser_list_dict
# **************************************************
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# **************************************************
# Новых ИД НЕТ для загрузки в таблицу adex_brand_list_dict
# **************************************************
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# **************************************************
# Новых ИД НЕТ для загрузки в таблицу adex_subbrand_list_dict
# **************************************************
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# **************************************************
# Новых ИД НЕТ для загрузки в таблицу adex_model_list_dict
# **************************************************
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# **************************************************
# Новых ИД НЕТ для загрузки в таблицу adex_article_list2_dict
# **************************************************
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# **************************************************
# Новых ИД НЕТ для загрузки в таблицу adex_article_list3_dict
# **************************************************
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# **************************************************
# Новых ИД НЕТ для загрузки в таблицу adex_article_list4_dict
# **************************************************

# %%
# Обновляем все справочники из ТВ Индекс
update_tv_index_dicts()
# Обновляем основной справочник объявлений
update_nat_tv_ad_dict()
# Out:
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Таблица: nat_tv_ad_dict успешно удалена в БД: mediascope_x5
# ##########
# Все ок. Подключились!
# Пустая таблица nat_tv_ad_dict успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Скрипт запущен 2025-06-10 19:29:52.108110
# Данные добавлены в БД: mediascope_x5, таблица: nat_tv_ad_dict
# Скрипт отработал 2025-06-10 19:29:52.659216
# Время выполнения задачи: 0:00:00.551106
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################

# %%
# загружаем в гугл докс Чистка список объяалений с флагом=2
query = query_for_google(report='media')
worksheet = config_media_costs.google_new_ads_media_invest['worksheet']

append_ads_to_google(query=query, worksheet=worksheet)
# Out:
# Все ок. Подключились!
# Загрузка завершена успешно
# Connection established successfully...
# DataFrame exported successfully...

# %%
# # Может возникнуть необходимость перезаписать кастомные поля в таблицах расходов
# # например - пересмотрели размер дисконта / изменили правила опеределения одной из кастомных колонок и тд.
# # В этом случае забираем из нашей БД из каждой таблицы расходов колонки, которые мы взяли из Медиаскопа
# # И пропускаем по тем же шагам обработки, которые применялись в первоначальной загрузке
# # По итогу - удаляем существующую таблицу в БД и на ее место записываем таблицу с новуми данными
# for media_type in config.media_type_dict.keys():
#     update_media_cost(media_type)
