# %%
import os

from time import sleep
import config
import config_tv_index
import config_media_costs
from config_search_funcs import get_subbrand_id_str
from nat_tv_ratings import get_nat_tv_reports
from media_costs import get_media_costs_report, get_mon_num_from_date
from create_dicts_tv_index import update_tv_index_dicts, update_nat_tv_ad_dict
from create_dicts_adex import create_adex_tables, download_adex_default_dicts, update_media_ads_dict, update_ad_dict_items, update_another_dicts, update_list_dicts, create_adex_views
from google_connector import append_ads_to_google
# Out:
# Все ок. Подключились!
# Загрузка завершена успешно
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314

# %%
# Обновляем все справочники из ТВ Индекс
update_tv_index_dicts()
# Обновляем основной справочник объявлений
update_nat_tv_ad_dict()

# загружаем в гугл докс Чистка список объяалений с флагом=2
query = config_tv_index.google_new_ads_nat_tv['query']
worksheet = config_tv_index.google_new_ads_nat_tv['worksheet']

append_ads_to_google(query=query, worksheet=worksheet)
# Out:
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Запрошены записи: 0 - 33
# Всего найдено записей: 33
#
# Все ок. Подключились!
# Скрипт запущен 2025-05-28 20:44:21.912329
# Данные добавлены в БД: mediascope_x5, таблица: tv_index_advertiser_list_dict
# Скрипт отработал 2025-05-28 20:44:21.930094
# Время выполнения задачи: 0:00:00.017765
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Запрошены записи: 0 - 730
# Всего найдено записей: 730
#
# Все ок. Подключились!
# Скрипт запущен 2025-05-28 20:44:22.002620
# Данные добавлены в БД: mediascope_x5, таблица: tv_index_brand_list_dict
# Скрипт отработал 2025-05-28 20:44:22.030621
# Время выполнения задачи: 0:00:00.028001
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Запрошены записи: 0 - 68
# Всего найдено записей: 68
#
# Запрошены записи: 0 - 795
# Всего найдено записей: 795
#
# Все ок. Подключились!
# Скрипт запущен 2025-05-28 20:44:22.128055
# Данные добавлены в БД: mediascope_x5, таблица: tv_index_subbrand_list_dict
# Скрипт отработал 2025-05-28 20:44:22.159940
# Время выполнения задачи: 0:00:00.031885
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Запрошены записи: 0 - 1022
# Всего найдено записей: 1022
#
# Все ок. Подключились!
# Скрипт запущен 2025-05-28 20:44:22.307638
# Данные добавлены в БД: mediascope_x5, таблица: tv_index_model_list_dict
# Скрипт отработал 2025-05-28 20:44:22.329732
# Время выполнения задачи: 0:00:00.022094
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Запрошены записи: 0 - 209
# Всего найдено записей: 209
#
# Все ок. Подключились!
# Скрипт запущен 2025-05-28 20:44:22.415048
# Данные добавлены в БД: mediascope_x5, таблица: tv_index_article_list2_dict
# Скрипт отработал 2025-05-28 20:44:22.431048
# Время выполнения задачи: 0:00:00.016000
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Запрошены записи: 0 - 472
# Всего найдено записей: 472
#
# Все ок. Подключились!
# Скрипт запущен 2025-05-28 20:44:22.484992
# Данные добавлены в БД: mediascope_x5, таблица: tv_index_article_list3_dict
# Скрипт отработал 2025-05-28 20:44:22.516182
# Время выполнения задачи: 0:00:00.031190
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Запрошены записи: 0 - 704
# Всего найдено записей: 704
#
# Все ок. Подключились!
# Скрипт запущен 2025-05-28 20:44:22.603461
# Данные добавлены в БД: mediascope_x5, таблица: tv_index_article_list4_dict
# Скрипт отработал 2025-05-28 20:44:22.626217
# Время выполнения задачи: 0:00:00.022756
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Запрошены записи: 0 - 31
# Всего найдено записей: 31
#
# Все ок. Подключились!
# Скрипт запущен 2025-05-28 20:44:22.699009
# Данные добавлены в БД: mediascope_x5, таблица: tv_index_audio_slogan_dict
# Скрипт отработал 2025-05-28 20:44:22.716009
# Время выполнения задачи: 0:00:00.017000
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Запрошены записи: 0 - 30
# Всего найдено записей: 30
#
# Все ок. Подключились!
# Скрипт запущен 2025-05-28 20:44:22.798156
# Данные добавлены в БД: mediascope_x5, таблица: tv_index_video_slogan_dict
# Скрипт отработал 2025-05-28 20:44:22.811750
# Время выполнения задачи: 0:00:00.013594
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Таблица: nat_tv_ad_dict успешно удалена в БД: mediascope_x5
# ##########
# Все ок. Подключились!
# Пустая таблица nat_tv_ad_dict успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Скрипт запущен 2025-05-28 20:44:36.919895
# Данные добавлены в БД: mediascope_x5, таблица: nat_tv_ad_dict
# Скрипт отработал 2025-05-28 20:44:37.064059
# Время выполнения задачи: 0:00:00.144164
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# Все ок. Подключились!
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\io\sql.py:2674, in SQLiteDatabase.execute(self, sql, params)
#    2673 try:
# -> 2674     cur.execute(sql, *args)
#    2675     return cur
#
# File C:\ProgramData\anaconda3\Lib\site-packages\turbodbc\exceptions.py:45, in translate_exceptions.<locals>.wrapper(*args, **kwds)
#      44 try:
# ---> 45     return f(*args, **kwds)
#      46 except InternError as e:
#
# File C:\ProgramData\anaconda3\Lib\site-packages\turbodbc\cursor.py:157, in Cursor.execute(self, sql, parameters)
#     156     buffer.flush()
# --> 157 return self._execute()
#
# File C:\ProgramData\anaconda3\Lib\site-packages\turbodbc\cursor.py:129, in Cursor._execute(self)
#     128 def _execute(self):
# --> 129     self.impl.execute()
#     130     self.rowcount = self.impl.get_row_count()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xcd in position 103: invalid continuation byte
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# Cell In[2], line 10
#       7 query = config_tv_index.google_new_ads_nat_tv['query']
#       8 worksheet = config_tv_index.google_new_ads_nat_tv['worksheet']
# ---> 10 append_ads_to_google(query=query, worksheet=worksheet)
#
# File ~\Desktop\Jupyter_notebook\43_Проекты_Рейтинги_и_расходы\02_02_version_3_X5\google_connector.py:72, in append_ads_to_google(query, worksheet)
#      69 def append_ads_to_google(query='', worksheet=''):
#      70     if query and worksheet:
#      71         # делаем запрос к БД, чтобы получить новые объявления
# ---> 72         nat_tv_new_ad_dict_df = get_mssql_table(config.db_name, query=query)
#      73         # создаем подключение к гуглу
#      74         client = create_connection(config.service)
#
# File ~\Desktop\Jupyter_notebook\43_Проекты_Рейтинги_и_расходы\02_02_version_3_X5\db_funcs.py:323, in get_mssql_table(db_name, table_name, query, conn_lst)
#     320     query = f'SELECT * FROM {table_name}'
#     322 warnings.simplefilter(action='ignore', category=UserWarning)
# --> 323 df = pd.read_sql(query, conn)
#     325 conn.close()
#     327 print('Загрузка завершена успешно')
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\io\sql.py:706, in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize, dtype_backend, dtype)
#     704 with pandasSQL_builder(con) as pandas_sql:
#     705     if isinstance(pandas_sql, SQLiteDatabase):
# --> 706         return pandas_sql.read_query(
#     707             sql,
#     708             index_col=index_col,
#     709             params=params,
#     710             coerce_float=coerce_float,
#     711             parse_dates=parse_dates,
#     712             chunksize=chunksize,
#     713             dtype_backend=dtype_backend,
#     714             dtype=dtype,
#     715         )
#     717     try:
#     718         _is_table_name = pandas_sql.has_table(sql)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\io\sql.py:2738, in SQLiteDatabase.read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype, dtype_backend)
#    2727 def read_query(
#    2728     self,
#    2729     sql,
#    (...)   2736     dtype_backend: DtypeBackend | Literal["numpy"] = "numpy",
#    2737 ) -> DataFrame | Iterator[DataFrame]:
# -> 2738     cursor = self.execute(sql, params)
#    2739     columns = [col_desc[0] for col_desc in cursor.description]
#    2741     if chunksize is not None:
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\io\sql.py:2686, in SQLiteDatabase.execute(self, sql, params)
#    2683     raise ex from inner_exc
#    2685 ex = DatabaseError(f"Execution failed on sql '{sql}': {exc}")
# -> 2686 raise ex from exc
#
# DatabaseError: Execution failed on sql '
#             from
#             	(select * from google_cleaning_adex_view
#                 union all
#                 select * from google_cleaning_tv_index_view) t1
#             ': 'utf-8' codec can't decode byte 0xcd in position 103: invalid continuation byte

# %%
# Обновляем справочники медиа инвестиций
for media_type, media_type_long in config.media_type_dict.items():
    # здесь загружаем недостающие ИД
    update_media_ads_dict(media_type)
    # здесь обновляем кастомные поля(флаг чистки, категория и тд) в справочнике объявлений
    update_ad_dict_items(media_type)
    update_another_dicts(media_type)
    update_list_dicts(media_type)

# %%
# загружаем в гугл докс Чистка список объяалений с флагом=2
query = config_media_costs.google_new_ads_media_invest['query']
worksheet = config_media_costs.google_new_ads_media_invest['worksheet']

append_ads_to_google(query=query, worksheet=worksheet)
