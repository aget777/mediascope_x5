# %%
import os
from time import sleep
from datetime import datetime
from dateutil.relativedelta import relativedelta

import config
import config_media_costs
import config_tv_index
import config_reg_tv

from media_costs import get_media_costs_report, get_mon_num_from_date, update_media_cost
from create_dicts_tv_index import update_tv_index_dicts, update_nat_tv_ad_dict
from create_dicts_adex import create_adex_tables, download_adex_default_dicts, update_media_ads_dict, update_ad_dict_items, update_another_dicts, update_list_dicts, create_adex_views

from nat_tv_ratings import create_nat_tv_tables, get_nat_tv_reports, update_nat_tv_fact
from create_dicts_tv_index import update_tv_index_dicts, update_nat_tv_ad_dict
from create_dicts_adex import create_adex_tables, download_adex_default_dicts, update_media_ads_dict, update_ad_dict_items, update_another_dicts, update_list_dicts, create_adex_views

from reg_tv_ratings import create_reg_tv_tables, get_reg_tv_reports

from config_search_funcs import get_subbrand_id_str
from google_connector import append_ads_to_google, query_for_google

start_date = '2023-01-01' # если дата начала НЕ указана, то start_date = Сегодня минус 3 дня минус 17 дней
end_date = '2023-12-31' #- ВКЛЮЧИТЕЛЬНО / если дата окончания НЕ указана, то end_date = Сегодня минус 3 дня

# start_date = '2025-03-01' # если дата начала НЕ указана, то start_date = Сегодня минус 3 дня минус 17 дней
# end_date = '' #- ВКЛЮЧИТЕЛЬНО / если дата окончания НЕ указана, то end_date = Сегодня минус 3 дня

# если нужно загрузить статистику по Медиаинвестициям и Обновить рейтинги за последние 3 месяца
# то ставим True, иначе False или просто ''
media_invest_flag = True # True / False

flag='first' #first / regular
print(f'База данных для записи: {config.db_name}')
# Out:
# Все ок. Подключились!
# Загрузка завершена успешно
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# База данных для записи: mediascope_x5

# %%
# #условия для отчетов ТВ индекс
# subbrand_id_str = get_subbrand_id_str(mon_num='360')
# special_ad_filter = f'{config_tv_index.nat_tv_ad_filter} AND subbrandId IN ({subbrand_id_str})'

# %%
# создаем пустые таблицы Фактов и Справочники
# Заполняем справоники по умолчанию данными config_media_costs.adex_defult_dicts
# Company / Ad_type / EState / 
if flag=='first':
    create_nat_tv_tables()
    sleep(10)
    # создаем все пустые таблицы
    create_adex_tables()
    sleep(10)
    create_reg_tv_tables()
    sleep(10)
    # наполняем данными справочники, которые НЕ обновляются
    download_adex_default_dicts()
    sleep(10)
    # создаем Представления
    create_adex_views()
# Out:
# Все ок. Подключились!
# Пустая таблица nat_tv_simple успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Пустая таблица nat_tv_buying успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Пустая таблица nat_tv_ad_dict успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Пустая таблица tv_index_region_dict успешно создана в БД mediascope_x5
# Запрошены записи: 0 - 28
# Всего найдено записей: 28
#
# Все ок. Подключились!
# Скрипт запущен 2025-05-28 12:09:41.474726
# Данные добавлены в БД: mediascope_x5, таблица: tv_index_region_dict
# Скрипт отработал 2025-05-28 12:09:41.491735
# Время выполнения задачи: 0:00:00.017009
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# Все ок. Подключились!
# Пустая таблица tv_index_tv_net_dict успешно создана в БД mediascope_x5
# Запрошены записи: 0 - 44
# Всего найдено записей: 44
#
# Все ок. Подключились!
# Скрипт запущен 2025-05-28 12:09:41.562897
# Данные добавлены в БД: mediascope_x5, таблица: tv_index_tv_net_dict
# Скрипт отработал 2025-05-28 12:09:41.580116
# Время выполнения задачи: 0:00:00.017219
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# Все ок. Подключились!
# Пустая таблица tv_index_tv_company_dict успешно создана в БД mediascope_x5
# Запрошены записи: 0 - 2425
# Всего найдено записей: 2425
#
# Все ок. Подключились!
# Скрипт запущен 2025-05-28 12:09:41.876279
# Данные добавлены в БД: mediascope_x5, таблица: tv_index_tv_company_dict
# Скрипт отработал 2025-05-28 12:09:41.986315
# Время выполнения задачи: 0:00:00.110036
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# Все ок. Подключились!
# Пустая таблица tv_index_ad_type_dict успешно создана в БД mediascope_x5
# Запрошены записи: 0 - 24
# Всего найдено записей: 24
#
# Все ок. Подключились!
# Скрипт запущен 2025-05-28 12:09:42.036664
# Данные добавлены в БД: mediascope_x5, таблица: tv_index_ad_type_dict
# Скрипт отработал 2025-05-28 12:09:42.050622
# Время выполнения задачи: 0:00:00.013958
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# Все ок. Подключились!
# Пустая таблица tv_index_distribution_dict успешно создана в БД mediascope_x5
# Запрошены записи: 0 - 4
# Всего найдено записей: 4
#
# Все ок. Подключились!
# Скрипт запущен 2025-05-28 12:09:42.090902
# Данные добавлены в БД: mediascope_x5, таблица: tv_index_distribution_dict
# Скрипт отработал 2025-05-28 12:09:42.108929
# Время выполнения задачи: 0:00:00.018027
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# Все ок. Подключились!
# Пустая таблица tv_index_advertiser_list_dict успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Пустая таблица tv_index_brand_list_dict успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Пустая таблица tv_index_subbrand_list_dict успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Пустая таблица tv_index_model_list_dict успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Пустая таблица tv_index_article_list2_dict успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Пустая таблица tv_index_article_list3_dict успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Пустая таблица tv_index_article_list4_dict успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Пустая таблица tv_index_audio_slogan_dict успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Пустая таблица tv_index_video_slogan_dict успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Пустая таблица adex_distribution_dict успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Пустая таблица adex_estate_dict успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Пустая таблица adex_regions_dict успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Пустая таблица media_tv_costs успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Пустая таблица adex_company_dict_tv успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Пустая таблица adex_ad_type_dict_tv успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Пустая таблица adex_audio_slogan_dict_tv успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Пустая таблица adex_video_slogan_dict_tv успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Пустая таблица adex_ad_dict_list_tv успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Пустая таблица media_radio_costs успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Пустая таблица adex_company_dict_radio успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Пустая таблица adex_ad_type_dict_radio успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Пустая таблица adex_ad_dict_list_radio успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Пустая таблица media_press_costs успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Пустая таблица adex_company_dict_press успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Пустая таблица adex_ad_type_dict_press успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Пустая таблица adex_ad_dict_list_press успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Пустая таблица media_outdoor_costs успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Пустая таблица adex_company_dict_outdoor успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Пустая таблица adex_ad_type_dict_outdoor успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Пустая таблица adex_network_dict_outdoor успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Пустая таблица adex_ad_dict_list_outdoor успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Пустая таблица adex_advertiser_list_dict успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Пустая таблица adex_brand_list_dict успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Пустая таблица adex_subbrand_list_dict успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Пустая таблица adex_model_list_dict успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Пустая таблица adex_article_list2_dict успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Пустая таблица adex_article_list3_dict успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Пустая таблица adex_article_list4_dict успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Пустая таблица reg_tv_simple успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Пустая таблица reg_tv_buying успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Пустая таблица reg_tv_ad_dict успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-05-28 12:10:12.391917
# Данные добавлены в БД: mediascope_x5, таблица: adex_distribution_dict
# Скрипт отработал 2025-05-28 12:10:12.422385
# Время выполнения задачи: 0:00:00.030468
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-05-28 12:10:12.428645
# Данные добавлены в БД: mediascope_x5, таблица: adex_estate_dict
# Скрипт отработал 2025-05-28 12:10:12.440645
# Время выполнения задачи: 0:00:00.012000
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-05-28 12:10:12.447645
# Данные добавлены в БД: mediascope_x5, таблица: adex_regions_dict
# Скрипт отработал 2025-05-28 12:10:12.453769
# Время выполнения задачи: 0:00:00.006124
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-05-28 12:10:12.500645
# Данные добавлены в БД: mediascope_x5, таблица: adex_company_dict_tv
# Скрипт отработал 2025-05-28 12:10:12.608423
# Время выполнения задачи: 0:00:00.107778
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-05-28 12:10:12.619643
# Данные добавлены в БД: mediascope_x5, таблица: adex_ad_type_dict_tv
# Скрипт отработал 2025-05-28 12:10:12.632529
# Время выполнения задачи: 0:00:00.012886
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-05-28 12:10:12.647638
# Данные добавлены в БД: mediascope_x5, таблица: adex_company_dict_radio
# Скрипт отработал 2025-05-28 12:10:12.661642
# Время выполнения задачи: 0:00:00.014004
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-05-28 12:10:12.670642
# Данные добавлены в БД: mediascope_x5, таблица: adex_ad_type_dict_radio
# Скрипт отработал 2025-05-28 12:10:12.681962
# Время выполнения задачи: 0:00:00.011320
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-05-28 12:10:12.735410
# Данные добавлены в БД: mediascope_x5, таблица: adex_company_dict_outdoor
# Скрипт отработал 2025-05-28 12:10:12.921392
# Время выполнения задачи: 0:00:00.185982
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-05-28 12:10:12.932810
# Данные добавлены в БД: mediascope_x5, таблица: adex_ad_type_dict_outdoor
# Скрипт отработал 2025-05-28 12:10:12.957977
# Время выполнения задачи: 0:00:00.025167
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-05-28 12:10:12.977585
# Данные добавлены в БД: mediascope_x5, таблица: adex_network_dict_outdoor
# Скрипт отработал 2025-05-28 12:10:13.028003
# Время выполнения задачи: 0:00:00.050418
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-05-28 12:10:13.069184
# Данные добавлены в БД: mediascope_x5, таблица: adex_company_dict_press
# Скрипт отработал 2025-05-28 12:10:13.158727
# Время выполнения задачи: 0:00:00.089543
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-05-28 12:10:13.171296
# Данные добавлены в БД: mediascope_x5, таблица: adex_ad_type_dict_press
# Скрипт отработал 2025-05-28 12:10:13.184777
# Время выполнения задачи: 0:00:00.013481
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# Все ок. Подключились!
# Создано Представление media_ad_dict_view
# ##########
# Все ок. Подключились!
# Создано Представление all_reports_ad_dict_view
# ##########
# Все ок. Подключились!
# Создано Представление media_ad_type_dict_view
# ##########
# Все ок. Подключились!
# Создано Представление media_costs_union_view
# ##########
# Все ок. Подключились!
# Создано Представление media_company_dict_view
# ##########
# Все ок. Подключились!
# Создано Представление ad_type_view
# ##########
# Все ок. Подключились!
# Создано Представление regions_view
# ##########
# Все ок. Подключились!
# Создано Представление articleList2_view
# ##########
# Все ок. Подключились!
# Создано Представление articleList3_view
# ##########
# Все ок. Подключились!
# Создано Представление articleList4_view
# ##########
# Все ок. Подключились!
# Создано Представление advertiserList_view
# ##########
# Все ок. Подключились!
# Создано Представление brandList_view
# ##########
# Все ок. Подключились!
# Создано Представление subBrandList_view
# ##########
# Все ок. Подключились!
# Создано Представление modelList_view
# ##########
# Все ок. Подключились!
# Создано Представление tv_video_slogan_view
# ##########
# Все ок. Подключились!
# Создано Представление tv_audio_slogan_view
# ##########
# Все ок. Подключились!
# Создано Представление standardDuration_view
# ##########
# Все ок. Подключились!
# Создано Представление media_type_view
# ##########
# Все ок. Подключились!
# Создано Представление media_type_detail_view
# ##########
# Все ок. Подключились!
# Создано Представление tv_type_ooh_reg_view
# ##########
# Все ок. Подключились!
# Создано Представление google_cleaning_adex_view
# ##########
# Все ок. Подключились!
# Создано Представление google_cleaning_tv_index_view
# ##########

# %%
"""
Если флаг first - создаем набор пустых таблиц-справочников / 
забираем статистику / заполняем таблицы фактов и справочник nat_tv_ad_dict
Если флаг regular - то грузим статистику и обновляем справочники
если start_date(дата начала) НЕ указана, то 
удаляем из БД - последние 17(сегодня-14-3) дней
перезаисываем статистику за этот период
если НЕ указана end_date(дата окончания) - ВКЛЮЧИТЕЛЬНО, то грузим данные до сегодня-3 дня
получаем статистику по отчету Simple и Buying
"""
# get_nat_tv_reports(start_date=start_date, end_date=end_date, ad_filter=special_ad_filter, flag=flag)
if flag=='regular' and media_invest_flag:
    cur_date = datetime.now().date()
    start_date = (cur_date  - relativedelta(months=2))
    start_date = start_date.replace(day=1)
    
get_nat_tv_reports(start_date=start_date, end_date=end_date, flag=flag)
# Out:
# Скрипт запущен 2025-05-28 12:10:49.569977
# Все ок. Подключились!
# Пустая таблица nat_tv_simple успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Пустая таблица nat_tv_buying успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Пустая таблица nat_tv_ad_dict успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Пустая таблица tv_index_region_dict успешно создана в БД mediascope_x5
# Запрошены записи: 0 - 28
# Всего найдено записей: 28
#
# Все ок. Подключились!
# Скрипт запущен 2025-05-28 12:10:49.651302
# Данные добавлены в БД: mediascope_x5, таблица: tv_index_region_dict
# Скрипт отработал 2025-05-28 12:10:49.672132
# Время выполнения задачи: 0:00:00.020830
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# Все ок. Подключились!
# Пустая таблица tv_index_tv_net_dict успешно создана в БД mediascope_x5
# Запрошены записи: 0 - 44
# Всего найдено записей: 44
#
# Все ок. Подключились!
# Скрипт запущен 2025-05-28 12:10:49.734198
# Данные добавлены в БД: mediascope_x5, таблица: tv_index_tv_net_dict
# Скрипт отработал 2025-05-28 12:10:49.751198
# Время выполнения задачи: 0:00:00.017000
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# Все ок. Подключились!
# Пустая таблица tv_index_tv_company_dict успешно создана в БД mediascope_x5
# Запрошены записи: 0 - 2425
# Всего найдено записей: 2425
#
# Все ок. Подключились!
# Скрипт запущен 2025-05-28 12:10:50.078716
# Данные добавлены в БД: mediascope_x5, таблица: tv_index_tv_company_dict
# Скрипт отработал 2025-05-28 12:10:50.172699
# Время выполнения задачи: 0:00:00.093983
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# Все ок. Подключились!
# Пустая таблица tv_index_ad_type_dict успешно создана в БД mediascope_x5
# Запрошены записи: 0 - 24
# Всего найдено записей: 24
#
# Все ок. Подключились!
# Скрипт запущен 2025-05-28 12:10:50.219956
# Данные добавлены в БД: mediascope_x5, таблица: tv_index_ad_type_dict
# Скрипт отработал 2025-05-28 12:10:50.253053
# Время выполнения задачи: 0:00:00.033097
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# Все ок. Подключились!
# Пустая таблица tv_index_distribution_dict успешно создана в БД mediascope_x5
# Запрошены записи: 0 - 4
# Всего найдено записей: 4
#
# Все ок. Подключились!
# Скрипт запущен 2025-05-28 12:10:50.301576
# Данные добавлены в БД: mediascope_x5, таблица: tv_index_distribution_dict
# Скрипт отработал 2025-05-28 12:10:50.314576
# Время выполнения задачи: 0:00:00.013000
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# Все ок. Подключились!
# Пустая таблица tv_index_advertiser_list_dict успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Пустая таблица tv_index_brand_list_dict успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Пустая таблица tv_index_subbrand_list_dict успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Пустая таблица tv_index_model_list_dict успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Пустая таблица tv_index_article_list2_dict успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Пустая таблица tv_index_article_list3_dict успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Пустая таблица tv_index_article_list4_dict успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Пустая таблица tv_index_audio_slogan_dict успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Пустая таблица tv_index_video_slogan_dict успешно создана в БД mediascope_x5
# **************************************************
# Забираем из БД НЕ ОБНОВЛЕННЫЙ справочник объявлений
# Все ок. Подключились!
# Загрузка завершена успешно
# **************************************************
#
# Загружаем отчет за период 2023-01-01 - 2023-12-31. Общее количество дней: 365
# **************************************************
#
#
# ==========Загружаем 2023-01-01. Отправляем задания на расчет
#
# -------------------- Забираем статистику по отчету Buying
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Расчет задачи (id: 4cea5d2b-ee72-41bf-8981-e03a77398e79) [= = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = ] время расчета: 0:03:02.770772
# Все ок. Подключились!
# Загрузка завершена успешно
# Записываем данные в таблицу фактов Buying
#
# Все ок. Подключились!
# Скрипт запущен 2025-05-28 12:13:58.750075
# Данные добавлены в БД: mediascope_x5, таблица: nat_tv_buying
# Скрипт отработал 2025-05-28 12:13:58.789934
# Время выполнения задачи: 0:00:00.039859
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
#
# **************************************************
#
# -------------------- Забираем статистику по отчету Simple
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
#
# Ждем выполнения
# Расчет задач (13) [ = = = = = ] время расчета: 0:00:29.764582
# Расчет завершен, получаем результат
# Собираем таблицу
# .............Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
#
# **************************************************
# Записываем данные в справочник объявлений TV_Index
#
# Все ок. Подключились!
# Скрипт запущен 2025-05-28 12:14:59.396723
# Данные добавлены в БД: mediascope_x5, таблица: nat_tv_ad_dict
# Скрипт отработал 2025-05-28 12:14:59.421280
# Время выполнения задачи: 0:00:00.024557
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# **************************************************
#
# Записываем данные в таблицу фактов Simple
#
# Все ок. Подключились!
# Скрипт запущен 2025-05-28 12:14:59.421280
# Данные добавлены в БД: mediascope_x5, таблица: nat_tv_simple
# Скрипт отработал 2025-05-28 12:14:59.574341
# Время выполнения задачи: 0:00:00.153061
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# **************************************************
#
#
# ==========Загружаем 2023-01-02. Отправляем задания на расчет
#
# -------------------- Забираем статистику по отчету Buying
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Расчет задачи (id: a6e309c7-c482-4089-b6ac-bb0a384f2c3d) [= = = = = = = = = ] время расчета: 0:00:28.318087
# Все ок. Подключились!
# Загрузка завершена успешно
# Записываем данные в таблицу фактов Buying
#
# Все ок. Подключились!
# Скрипт запущен 2025-05-28 12:15:34.434518
# Данные добавлены в БД: mediascope_x5, таблица: nat_tv_buying
# Скрипт отработал 2025-05-28 12:15:34.544599
# Время выполнения задачи: 0:00:00.110081
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
#
# **************************************************
#
# -------------------- Забираем статистику по отчету Simple
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
#
# Ждем выполнения
# Расчет задач (13) [ = = = = ] время расчета: 0:00:23.819169
# Расчет завершен, получаем результат
# Собираем таблицу
# .............Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
#
# **************************************************
# Записываем данные в справочник объявлений TV_Index
#
# Все ок. Подключились!
# Скрипт запущен 2025-05-28 12:16:31.310623
# Данные добавлены в БД: mediascope_x5, таблица: nat_tv_ad_dict
# Скрипт отработал 2025-05-28 12:16:31.341875
# Время выполнения задачи: 0:00:00.031252
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# **************************************************
#
# Записываем данные в таблицу фактов Simple
#
# Все ок. Подключились!
# Скрипт запущен 2025-05-28 12:16:31.341875
# Данные добавлены в БД: mediascope_x5, таблица: nat_tv_simple
# Скрипт отработал 2025-05-28 12:16:32.393372
# Время выполнения задачи: 0:00:01.051497
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# **************************************************
#
#
# ==========Загружаем 2023-01-03. Отправляем задания на расчет
#
# -------------------- Забираем статистику по отчету Buying
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Расчет задачи (id: 06ea9df1-d075-4dca-a694-484da5a7b4b6) [= = = = = = = = = = = = = ] время расчета: 0:00:40.381232
# Все ок. Подключились!
# Загрузка завершена успешно
# Записываем данные в таблицу фактов Buying
#
# Все ок. Подключились!
# Скрипт запущен 2025-05-28 12:17:19.216049
# Данные добавлены в БД: mediascope_x5, таблица: nat_tv_buying
# Скрипт отработал 2025-05-28 12:17:19.308290
# Время выполнения задачи: 0:00:00.092241
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
#
# **************************************************
#
# -------------------- Забираем статистику по отчету Simple
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
#
# Ждем выполнения
# Расчет задач (13) [ = = = = ] время расчета: 0:00:23.821752
# Расчет завершен, получаем результат
# Собираем таблицу
# .............Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
#
# **************************************************
# Записываем данные в справочник объявлений TV_Index
#
# Все ок. Подключились!
# Скрипт запущен 2025-05-28 12:18:16.126073
# Данные добавлены в БД: mediascope_x5, таблица: nat_tv_ad_dict
# Скрипт отработал 2025-05-28 12:18:16.157107
# Время выполнения задачи: 0:00:00.031034
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# **************************************************
#
# Записываем данные в таблицу фактов Simple
#
# Все ок. Подключились!
# Скрипт запущен 2025-05-28 12:18:16.172837
# Данные добавлены в БД: mediascope_x5, таблица: nat_tv_simple
# Скрипт отработал 2025-05-28 12:18:17.102047
# Время выполнения задачи: 0:00:00.929210
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# **************************************************
#
#
# ==========Загружаем 2023-01-04. Отправляем задания на расчет
#
# -------------------- Забираем статистику по отчету Buying
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Расчет задачи (id: 11eb6921-f89d-4493-90b5-ea45faa3e896) [= = = = = = = = ] время расчета: 0:00:25.311308
# Все ок. Подключились!
# Загрузка завершена успешно
# Записываем данные в таблицу фактов Buying
#
# Все ок. Подключились!
# Скрипт запущен 2025-05-28 12:18:48.530064
# Данные добавлены в БД: mediascope_x5, таблица: nat_tv_buying
# Скрипт отработал 2025-05-28 12:18:48.670995
# Время выполнения задачи: 0:00:00.140931
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
#
# **************************************************
#
# -------------------- Забираем статистику по отчету Simple
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
#
# Ждем выполнения
# Расчет задач (13) [ = = = = ] время расчета: 0:00:23.821495
# Расчет завершен, получаем результат
# Собираем таблицу
# .............Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
#
# **************************************************
# Записываем данные в справочник объявлений TV_Index
#
# Все ок. Подключились!
# Скрипт запущен 2025-05-28 12:19:46.088382
# Данные добавлены в БД: mediascope_x5, таблица: nat_tv_ad_dict
# Скрипт отработал 2025-05-28 12:19:46.112683
# Время выполнения задачи: 0:00:00.024301
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# **************************************************
#
# Записываем данные в таблицу фактов Simple
#
# Все ок. Подключились!
# Скрипт запущен 2025-05-28 12:19:46.122542
# Данные добавлены в БД: mediascope_x5, таблица: nat_tv_simple
# Скрипт отработал 2025-05-28 12:19:47.086866
# Время выполнения задачи: 0:00:00.964324
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# **************************************************
#
#
# ==========Загружаем 2023-01-05. Отправляем задания на расчет
#
# -------------------- Забираем статистику по отчету Buying
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Расчет задачи (id: 994ac12c-52c5-4f2a-babe-edff77037f32) [= = = = = = = = = = = = = = = ] время расчета: 0:00:46.393038
# Все ок. Подключились!
# Загрузка завершена успешно
# Записываем данные в таблицу фактов Buying
#
# Все ок. Подключились!
# Скрипт запущен 2025-05-28 12:20:40.375069
# Данные добавлены в БД: mediascope_x5, таблица: nat_tv_buying
# Скрипт отработал 2025-05-28 12:20:40.501269
# Время выполнения задачи: 0:00:00.126200
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
#
# **************************************************
#
# -------------------- Забираем статистику по отчету Simple
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
#
# Ждем выполнения
# Расчет задач (13) [ = = = = ] время расчета: 0:00:23.815127
# Расчет завершен, получаем результат
# Собираем таблицу
# .............Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
#
# **************************************************
# Записываем данные в справочник объявлений TV_Index
#
# Все ок. Подключились!
# Скрипт запущен 2025-05-28 12:21:37.959834
# Данные добавлены в БД: mediascope_x5, таблица: nat_tv_ad_dict
# Скрипт отработал 2025-05-28 12:21:37.974835
# Время выполнения задачи: 0:00:00.015001
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# **************************************************
#
# Записываем данные в таблицу фактов Simple
#
# Все ок. Подключились!
# Скрипт запущен 2025-05-28 12:21:37.984835
# Данные добавлены в БД: mediascope_x5, таблица: nat_tv_simple
# Скрипт отработал 2025-05-28 12:21:39.027332
# Время выполнения задачи: 0:00:01.042497
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# **************************************************
#
#
# ==========Загружаем 2023-01-06. Отправляем задания на расчет
#
# -------------------- Забираем статистику по отчету Buying
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Расчет задачи (id: ac3a0b18-29b9-4a5f-aa62-eb2afecae90c) [= = = = = = = = = ] время расчета: 0:00:28.240796
# Все ок. Подключились!
# Загрузка завершена успешно
# Записываем данные в таблицу фактов Buying
#
# Все ок. Подключились!
# Скрипт запущен 2025-05-28 12:22:12.895010
# Данные добавлены в БД: mediascope_x5, таблица: nat_tv_buying
# Скрипт отработал 2025-05-28 12:22:12.989650
# Время выполнения задачи: 0:00:00.094640
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
#
# **************************************************
#
# -------------------- Забираем статистику по отчету Simple
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
#
# Ждем выполнения
# Расчет задач (13) [ = = = = = ] время расчета: 0:00:29.732066
# Расчет завершен, получаем результат
# Собираем таблицу
# .............Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
#
# **************************************************
# Записываем данные в справочник объявлений TV_Index
#
# Все ок. Подключились!
# Скрипт запущен 2025-05-28 12:23:16.409651
# Данные добавлены в БД: mediascope_x5, таблица: nat_tv_ad_dict
# Скрипт отработал 2025-05-28 12:23:16.422649
# Время выполнения задачи: 0:00:00.012998
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# **************************************************
#
# Записываем данные в таблицу фактов Simple
#
# Все ок. Подключились!
# Скрипт запущен 2025-05-28 12:23:16.435649
# Данные добавлены в БД: mediascope_x5, таблица: nat_tv_simple
# Скрипт отработал 2025-05-28 12:23:17.601502
# Время выполнения задачи: 0:00:01.165853
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# **************************************************
#
#
# ==========Загружаем 2023-01-07. Отправляем задания на расчет
#
# -------------------- Забираем статистику по отчету Buying
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Расчет задачи (id: 8894b287-186f-4c8b-b95b-781387efb163) [= = = = = = ] время расчета: 0:00:19.174389
# Все ок. Подключились!
# Загрузка завершена успешно
# Записываем данные в таблицу фактов Buying
#
# Все ок. Подключились!
# Скрипт запущен 2025-05-28 12:23:42.995164
# Данные добавлены в БД: mediascope_x5, таблица: nat_tv_buying
# Скрипт отработал 2025-05-28 12:23:43.164489
# Время выполнения задачи: 0:00:00.169325
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
#
# **************************************************
#
# -------------------- Забираем статистику по отчету Simple
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
#
# Ждем выполнения
# Расчет задач (13) [ = = = ] время расчета: 0:00:17.865738
# Расчет завершен, получаем результат
# Собираем таблицу
# .............Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
#
# **************************************************
# Записываем данные в справочник объявлений TV_Index
#
# Все ок. Подключились!
# Скрипт запущен 2025-05-28 12:24:35.293789
# Данные добавлены в БД: mediascope_x5, таблица: nat_tv_ad_dict
# Скрипт отработал 2025-05-28 12:24:35.309480
# Время выполнения задачи: 0:00:00.015691
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# **************************************************
#
# Записываем данные в таблицу фактов Simple
#
# Все ок. Подключились!
# Скрипт запущен 2025-05-28 12:24:35.346965
# Данные добавлены в БД: mediascope_x5, таблица: nat_tv_simple
# Скрипт отработал 2025-05-28 12:24:36.717913
# Время выполнения задачи: 0:00:01.370948
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# **************************************************
#
#
# ==========Загружаем 2023-01-08. Отправляем задания на расчет
#
# -------------------- Забираем статистику по отчету Buying
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Расчет задачи (id: 8bf16540-3680-4c4a-8dfd-9bfae77a1dd4) [= = = = = = = = = = = = = = = = = ] время расчета: 0:00:52.510142
# Все ок. Подключились!
# Загрузка завершена успешно
# Записываем данные в таблицу фактов Buying
#
# Все ок. Подключились!
# Скрипт запущен 2025-05-28 12:25:36.130830
# Данные добавлены в БД: mediascope_x5, таблица: nat_tv_buying
# Скрипт отработал 2025-05-28 12:25:36.267876
# Время выполнения задачи: 0:00:00.137046
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
#
# **************************************************
#
# -------------------- Забираем статистику по отчету Simple
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
#
# Ждем выполнения
# Расчет задач (13) [ = = = = ] время расчета: 0:00:23.774904
# Расчет завершен, получаем результат
# Собираем таблицу
# .............Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
#
# **************************************************
# Записываем данные в справочник объявлений TV_Index
#
# Все ок. Подключились!
# Скрипт запущен 2025-05-28 12:26:34.922229
# Данные добавлены в БД: mediascope_x5, таблица: nat_tv_ad_dict
# Скрипт отработал 2025-05-28 12:26:34.957345
# Время выполнения задачи: 0:00:00.035116
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# **************************************************
#
# Записываем данные в таблицу фактов Simple
#
# Все ок. Подключились!
# Скрипт запущен 2025-05-28 12:26:34.969339
# Данные добавлены в БД: mediascope_x5, таблица: nat_tv_simple
# Скрипт отработал 2025-05-28 12:26:36.538805
# Время выполнения задачи: 0:00:01.569466
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# **************************************************
#
#
# ==========Загружаем 2023-01-09. Отправляем задания на расчет
#
# -------------------- Забираем статистику по отчету Buying
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Расчет задачи (id: a95ec6fd-29c2-498f-a842-eb2629d2e89e) [= = = = = = = = = = = = ] время расчета: 0:00:37.348194
# Все ок. Подключились!
# Загрузка завершена успешно
# Записываем данные в таблицу фактов Buying
#
# Все ок. Подключились!
# Скрипт запущен 2025-05-28 12:27:20.566468
# Данные добавлены в БД: mediascope_x5, таблица: nat_tv_buying
# Скрипт отработал 2025-05-28 12:27:20.714041
# Время выполнения задачи: 0:00:00.147573
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
#
# **************************************************
#
# -------------------- Забираем статистику по отчету Simple
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
#
# Ждем выполнения
# Расчет задач (13) [ = = = ] время расчета: 0:00:17.874301
# Расчет завершен, получаем результат
# Собираем таблицу
# .............Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
#
# **************************************************
# Записываем данные в справочник объявлений TV_Index
#
# Все ок. Подключились!
# Скрипт запущен 2025-05-28 12:28:13.310556
# Данные добавлены в БД: mediascope_x5, таблица: nat_tv_ad_dict
# Скрипт отработал 2025-05-28 12:28:13.326189
# Время выполнения задачи: 0:00:00.015633
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# **************************************************
#
# Записываем данные в таблицу фактов Simple
#
# Все ок. Подключились!
# Скрипт запущен 2025-05-28 12:28:13.351695
# Данные добавлены в БД: mediascope_x5, таблица: nat_tv_simple
# Скрипт отработал 2025-05-28 12:28:14.926792
# Время выполнения задачи: 0:00:01.575097
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# **************************************************
#
#
# ==========Загружаем 2023-01-10. Отправляем задания на расчет
#
# -------------------- Забираем статистику по отчету Buying
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Расчет задачи (id: 52a00629-6553-4219-bbc4-d0060c90376b) [= = = = = = = = = = = = = = = = = = = = = = = = ] время расчета: 0:01:13.696915
# Все ок. Подключились!
# Загрузка завершена успешно
# Записываем данные в таблицу фактов Buying
#
# Все ок. Подключились!
# Скрипт запущен 2025-05-28 12:29:35.108940
# Данные добавлены в БД: mediascope_x5, таблица: nat_tv_buying
# Скрипт отработал 2025-05-28 12:29:35.227255
# Время выполнения задачи: 0:00:00.118315
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
#
# **************************************************
#
# -------------------- Забираем статистику по отчету Simple
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
#
# Ждем выполнения
# Расчет задач (13) [ = = = = = = = = = = = = = = = = ] время расчета: 0:01:35.435417
# Расчет завершен, получаем результат
# Собираем таблицу
# .............Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
#
# **************************************************
# Записываем данные в справочник объявлений TV_Index
#
# Все ок. Подключились!
# Скрипт запущен 2025-05-28 12:31:44.977412
# Данные добавлены в БД: mediascope_x5, таблица: nat_tv_ad_dict
# Скрипт отработал 2025-05-28 12:31:45.000400
# Время выполнения задачи: 0:00:00.022988
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# **************************************************
#
# Записываем данные в таблицу фактов Simple
#
# Все ок. Подключились!
# Скрипт запущен 2025-05-28 12:31:45.012741
# Данные добавлены в БД: mediascope_x5, таблица: nat_tv_simple
# Скрипт отработал 2025-05-28 12:31:46.563892
# Время выполнения задачи: 0:00:01.551151
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# **************************************************
#
#
# ==========Загружаем 2023-01-11. Отправляем задания на расчет
#
# -------------------- Забираем статистику по отчету Buying
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Расчет задачи (id:
# Данные добавлены в БД: mediascope_x5, таблица: nat_tv_ad_dict
# Скрипт отработал 2025-05-28 16:26:41.216871
# Время выполнения задачи: 0:00:00.023089
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# **************************************************
#
# Записываем данные в таблицу фактов Simple
#
# Все ок. Подключились!
# Скрипт запущен 2025-05-28 16:26:41.233874
# Ошибка в файле nat_tv_simple
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~\Desktop\Jupyter_notebook\43_Проекты_Рейтинги_и_расходы\02_02_version_3_X5\db_funcs.py:274, in downloadTableToDB(db_name, table_name, df)
#     269 sql = f"""
#     270 INSERT INTO {table_name} {colunas}
#     271 VALUES {sql_val}
#     272 """
# --> 274 cursor.executemanycolumns(sql, values)
#     275 conn.commit()
#
# File C:\ProgramData\anaconda3\Lib\site-packages\turbodbc\exceptions.py:45, in translate_exceptions.<locals>.wrapper(*args, **kwds)
#      44 try:
# ---> 45     return f(*args, **kwds)
#      46 except InternError as e:
#
# File C:\ProgramData\anaconda3\Lib\site-packages\turbodbc\cursor.py:205, in Cursor.executemanycolumns(self, sql, columns)
#     203 self.impl.prepare(sql)
# --> 205 if _has_arrow_support():
#     206     import pyarrow as pa
#
# File C:\ProgramData\anaconda3\Lib\site-packages\turbodbc\cursor.py:32, in _has_arrow_support()
#      31 try:
# ---> 32     import turbodbc.arrow_support  # noqa: F401
#      34     return True
#
# File C:\ProgramData\anaconda3\Lib\site-packages\turbodbc\arrow_support.py:9
#       8     for lib_dir in pyarrow.get_library_dirs():
# ----> 9         os.add_dll_directory(lib_dir)
#      11 from turbodbc_arrow_support import *
#
# File <frozen os>:1119, in add_dll_directory(path)
#
# FileNotFoundError: [WinError 206] Имя файла или его расширение имеет слишком большую длину: 'C:\\ProgramData\\anaconda3\\Library\\lib'
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 17
#      14     start_date = (cur_date  - relativedelta(months=2))
#      15     start_date = start_date.replace(day=1)
# ---> 17 get_nat_tv_reports(start_date=start_date, end_date=end_date, flag=flag)
#
# File ~\Desktop\Jupyter_notebook\43_Проекты_Рейтинги_и_расходы\02_02_version_3_X5\nat_tv_ratings.py:288, in get_nat_tv_reports(ad_filter, start_date, end_date, flag)
#     286 print('Записываем данные в таблицу фактов Simple')
#     287 print()
# --> 288 downloadTableToDB(config.db_name, config_tv_index.nat_tv_simple, df_simple_final)
#     290 print(sep_str)
#     291 print()
#
# File ~\Desktop\Jupyter_notebook\43_Проекты_Рейтинги_и_расходы\02_02_version_3_X5\db_funcs.py:285, in downloadTableToDB(db_name, table_name, df)
#     283     cursor.close()
#     284     print(f'Ошибка в файле {table_name}')
# --> 285     print(exception)
#     288 conn.close()
#     289 cursor.close()
#
# NameError: name 'exception' is not defined

# %%
# Обновляем все справочники из ТВ Индекс
update_tv_index_dicts()
sleep(10)
# Обновляем основной справочник объявлений
update_nat_tv_ad_dict()

# %%
# # условия для фильра МЕдиа инвестиции
# subbrand_id_str = get_subbrand_id_str(mon_num='360')
# special_ad_filter = f'{config_media_costs.main_filter_str} AND t10.sbid in ({subbrand_id_str})'

# %%
# забираем статистику по каждому Медиа за указанный период
for key, value in config.media_type_dict.items():
    get_media_costs_report(start_date=start_date, end_date=end_date, media_type=key,  flag=flag)
    # get_media_costs_report(media_type=key,  main_filter=special_ad_filter, flag=flag)

# %%
for media_type, media_type_long in config.media_type_dict.items():
    # здесь загружаем недостающие ИД
    update_media_ads_dict(media_type)
    # здесь обновляем кастомные поля(флаг чистки, категория и тд) в справочнике объявлений
    update_ad_dict_items(media_type)
    update_another_dicts(media_type)
    update_list_dicts(media_type)

# %%
# загружаем в гугл докс Чистка список объяалений с флагом=2
query = query_for_google(report='media')
worksheet = config_media_costs.google_new_ads_media_invest['worksheet']

append_ads_to_google(query=query, worksheet=worksheet)
