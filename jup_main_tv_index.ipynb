# %%
import os

from time import sleep
import config
import config_tv_index
import config_media_costs
from config_search_funcs import get_subbrand_id_str
from nat_tv_ratings import get_nat_tv_reports, update_nat_tv_fact
from create_dicts_tv_index import update_tv_index_dicts, update_nat_tv_ad_dict
from create_dicts_adex import create_adex_tables, download_adex_default_dicts, update_media_ads_dict, update_ad_dict_items, update_another_dicts, update_list_dicts, create_adex_views
from google_connector import append_ads_to_google, query_for_google

# start_date = '2025-05-10' # если дата начала НЕ указана, то start_date = Сегодня минус 3 дня минус 17 дней
# end_date = '' #'2025-02-09' #- ВКЛЮЧИТЕЛЬНО / если дата окончания НЕ указана, то end_date = Сегодня минус 3 дня

flag='regular' #first / regular


print(f'База данных для записи: {config.db_name}')
# Out:
# Все ок. Подключились!
# Загрузка завершена успешно
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# База данных для записи: mediascope_x5

# %%
# ПЕРЕД загрузкой Обновляем все справочники из ТВ Индекс
# и ПОСЛЕ тоже обновим
update_tv_index_dicts()
sleep(10)
# Обновляем основной справочник объявлений
update_nat_tv_ad_dict()
# Out:
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Таблица: nat_tv_ad_dict успешно удалена в БД: mediascope_x5
# ##########
# Все ок. Подключились!
# Пустая таблица nat_tv_ad_dict успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Скрипт запущен 2025-06-04 14:04:05.032880
# Данные добавлены в БД: mediascope_x5, таблица: nat_tv_ad_dict
# Скрипт отработал 2025-06-04 14:04:05.487229
# Время выполнения задачи: 0:00:00.454349
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################

# %%
# Если флаг first - создаем набор пустых таблиц-справочников / 
# забираем статистику / заполняем таблицы фактов и справочник nat_tv_ad_dict
# Если флаг regular - то грузим статистику и обновляем справочники
# если start_date(дата начала) НЕ указана, то 
# удаляем из БД - последние 17(сегодня-14-3) дней
# перезаисываем статистику за этот период
# если НЕ указана end_date(дата окончания) - ВКЛЮЧИТЕЛЬНО, то грузим данные до сегодня-3 дня
# получаем статистику по отчету Simple и Buying
start_date =  start_date if 'start_date' in globals() else ''
end_date = end_date if 'end_date' in globals() else ''

get_nat_tv_reports(start_date=start_date, end_date=end_date, flag=flag)
# get_nat_tv_reports(flag=flag)
# Out:
# Скрипт запущен 2025-06-04 14:11:42.200058
# **************************************************
# Забираем из БД НЕ ОБНОВЛЕННЫЙ справочник объявлений
# Все ок. Подключились!
# Загрузка завершена успешно
# **************************************************
#
# **************************************************
# Удалем строки из таблицы: nat_tv_simple и nat_tv_buying по условию: researchDate >= '2025-05-18' and researchDate <= '2025-06-01'
#
# Все ок. Подключились!
# Строки с условием WHERE researchDate >= '2025-05-18' and researchDate <= '2025-06-01' удалены из Таблицы: nat_tv_simple в БД: mediascope_x5
# ##########
# Все ок. Подключились!
# Строки с условием WHERE researchDate >= '2025-05-18' and researchDate <= '2025-06-01' удалены из Таблицы: nat_tv_buying в БД: mediascope_x5
# ##########
#
#
# Загружаем отчет за период 2025-05-18 - 2025-06-01. Общее количество дней: 15
# **************************************************
#
#
# ==========Загружаем 2025-05-18. Отправляем задания на расчет
#
# -------------------- Забираем статистику по отчету Buying
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Расчет задачи (id: 2c6ee8b9-f00b-4b08-8c24-e6a136aeaee9) [= = = = = = = = = ] время расчета: 0:00:28.249385
# Все ок. Подключились!
# Загрузка завершена успешно
# Записываем данные в таблицу фактов Buying
#
# Все ок. Подключились!
# Скрипт запущен 2025-06-04 14:12:36.109861
# Данные добавлены в БД: mediascope_x5, таблица: nat_tv_buying
# Скрипт отработал 2025-06-04 14:12:36.223733
# Время выполнения задачи: 0:00:00.113872
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
#
# **************************************************
#
# -------------------- Забираем статистику по отчету Simple
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
#
# Ждем выполнения
# Расчет задач (13) [ = = = ] время расчета: 0:00:17.866224
# Расчет завершен, получаем результат
# Собираем таблицу
# .............Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
#
# **************************************************
# Записываем данные в справочник объявлений TV_Index
#
# Все ок. Подключились!
# Скрипт запущен 2025-06-04 14:13:26.955568
# Данные добавлены в БД: mediascope_x5, таблица: nat_tv_ad_dict
# Скрипт отработал 2025-06-04 14:13:26.971139
# Время выполнения задачи: 0:00:00.015571
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# **************************************************
#
# Записываем данные в таблицу фактов Simple
#
# Все ок. Подключились!
# Скрипт запущен 2025-06-04 14:13:26.976138
# Данные добавлены в БД: mediascope_x5, таблица: nat_tv_simple
# Скрипт отработал 2025-06-04 14:13:28.060001
# Время выполнения задачи: 0:00:01.083863
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# **************************************************
#
#
# ==========Загружаем 2025-05-19. Отправляем задания на расчет
#
# -------------------- Забираем статистику по отчету Buying
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Расчет задачи (id: 383784c6-0008-4995-b831-3a9012d0bc90) [= = = = = = = = = = = = = = ] время расчета: 0:00:43.456835
# Все ок. Подключились!
# Загрузка завершена успешно
# Записываем данные в таблицу фактов Buying
#
# Все ок. Подключились!
# Скрипт запущен 2025-06-04 14:14:18.070678
# Данные добавлены в БД: mediascope_x5, таблица: nat_tv_buying
# Скрипт отработал 2025-06-04 14:14:18.195250
# Время выполнения задачи: 0:00:00.124572
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
#
# **************************************************
#
# -------------------- Забираем статистику по отчету Simple
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
#
# Ждем выполнения
# Расчет задач (13) [ = = = = ] время расчета: 0:00:23.817336
# Расчет завершен, получаем результат
# Собираем таблицу
# .............Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
#
# **************************************************
# Записываем данные в справочник объявлений TV_Index
#
# Все ок. Подключились!
# Скрипт запущен 2025-06-04 14:15:16.733265
# Данные добавлены в БД: mediascope_x5, таблица: nat_tv_ad_dict
# Скрипт отработал 2025-06-04 14:15:16.749263
# Время выполнения задачи: 0:00:00.015998
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# **************************************************
#
# Записываем данные в таблицу фактов Simple
#
# Все ок. Подключились!
# Скрипт запущен 2025-06-04 14:15:16.756263
# Данные добавлены в БД: mediascope_x5, таблица: nat_tv_simple
# Скрипт отработал 2025-06-04 14:15:17.612476
# Время выполнения задачи: 0:00:00.856213
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# **************************************************
#
#
# ==========Загружаем 2025-05-20. Отправляем задания на расчет
#
# -------------------- Забираем статистику по отчету Buying
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Расчет задачи (id: 90a9196b-6df2-4e07-bc96-4be39b1f9d5f) [= = = = = = = = = = = = = ] время расчета: 0:00:40.362103
# Все ок. Подключились!
# Загрузка завершена успешно
# Записываем данные в таблицу фактов Buying
#
# Все ок. Подключились!
# Скрипт запущен 2025-06-04 14:16:03.432943
# Данные добавлены в БД: mediascope_x5, таблица: nat_tv_buying
# Скрипт отработал 2025-06-04 14:16:03.522279
# Время выполнения задачи: 0:00:00.089336
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
#
# **************************************************
#
# -------------------- Забираем статистику по отчету Simple
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
#
# Ждем выполнения
# Расчет задач (13) [ = = = ] время расчета: 0:00:17.962676
# Расчет завершен, получаем результат
# Собираем таблицу
# .............Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
#
# **************************************************
# Записываем данные в справочник объявлений TV_Index
#
# Все ок. Подключились!
# Скрипт запущен 2025-06-04 14:16:54.754359
# Данные добавлены в БД: mediascope_x5, таблица: nat_tv_ad_dict
# Скрипт отработал 2025-06-04 14:16:54.766362
# Время выполнения задачи: 0:00:00.012003
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# **************************************************
#
# Записываем данные в таблицу фактов Simple
#
# Все ок. Подключились!
# Скрипт запущен 2025-06-04 14:16:54.781507
# Данные добавлены в БД: mediascope_x5, таблица: nat_tv_simple
# Скрипт отработал 2025-06-04 14:16:55.461186
# Время выполнения задачи: 0:00:00.679679
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# **************************************************
#
#
# ==========Загружаем 2025-05-21. Отправляем задания на расчет
#
# -------------------- Забираем статистику по отчету Buying
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Расчет задачи (id: 55b2ea38-6eb5-4778-9d4e-3779bcd873de) [= = = = = = = = = = = = ] время расчета: 0:00:37.384001
# Все ок. Подключились!
# Загрузка завершена успешно
# Записываем данные в таблицу фактов Buying
#
# Все ок. Подключились!
# Скрипт запущен 2025-06-04 14:17:38.755134
# Данные добавлены в БД: mediascope_x5, таблица: nat_tv_buying
# Скрипт отработал 2025-06-04 14:17:38.821257
# Время выполнения задачи: 0:00:00.066123
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
#
# **************************************************
#
# -------------------- Забираем статистику по отчету Simple
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
#
# Ждем выполнения
# Расчет задач (13) [ = = = = ] время расчета: 0:00:23.870155
# Расчет завершен, получаем результат
# Собираем таблицу
# .............Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
#
# **************************************************
# Записываем данные в справочник объявлений TV_Index
#
# Все ок. Подключились!
# Скрипт запущен 2025-06-04 14:18:37.101114
# Данные добавлены в БД: mediascope_x5, таблица: nat_tv_ad_dict
# Скрипт отработал 2025-06-04 14:18:37.114114
# Время выполнения задачи: 0:00:00.013000
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# **************************************************
#
# Записываем данные в таблицу фактов Simple
#
# Все ок. Подключились!
# Скрипт запущен 2025-06-04 14:18:37.119716
# Данные добавлены в БД: mediascope_x5, таблица: nat_tv_simple
# Скрипт отработал 2025-06-04 14:18:37.768791
# Время выполнения задачи: 0:00:00.649075
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# **************************************************
#
#
# ==========Загружаем 2025-05-22. Отправляем задания на расчет
#
# -------------------- Забираем статистику по отчету Buying
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Расчет задачи (id: 5931a9ce-60c3-4a6b-b363-5e21931bac58) [= = = = = = = = ] время расчета: 0:00:25.245249
# Все ок. Подключились!
# Загрузка завершена успешно
# Записываем данные в таблицу фактов Buying
#
# Все ок. Подключились!
# Скрипт запущен 2025-06-04 14:19:08.836400
# Данные добавлены в БД: mediascope_x5, таблица: nat_tv_buying
# Скрипт отработал 2025-06-04 14:19:08.909673
# Время выполнения задачи: 0:00:00.073273
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
#
# **************************************************
#
# -------------------- Забираем статистику по отчету Simple
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
#
# Ждем выполнения
# Расчет задач (13) [ = = = ] время расчета: 0:00:17.902446
# Расчет завершен, получаем результат
# Собираем таблицу
# .............Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
#
# **************************************************
# Записываем данные в справочник объявлений TV_Index
#
# Все ок. Подключились!
# Скрипт запущен 2025-06-04 14:20:00.403440
# Данные добавлены в БД: mediascope_x5, таблица: nat_tv_ad_dict
# Скрипт отработал 2025-06-04 14:20:00.416581
# Время выполнения задачи: 0:00:00.013141
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# **************************************************
#
# Записываем данные в таблицу фактов Simple
#
# Все ок. Подключились!
# Скрипт запущен 2025-06-04 14:20:00.426582
# Данные добавлены в БД: mediascope_x5, таблица: nat_tv_simple
# Скрипт отработал 2025-06-04 14:20:01.051877
# Время выполнения задачи: 0:00:00.625295
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# **************************************************
#
#
# ==========Загружаем 2025-05-23. Отправляем задания на расчет
#
# -------------------- Забираем статистику по отчету Buying
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Расчет задачи (id: d9214ffa-3110-4af2-8d2c-b5ce3b9a0039) [= = = = = = = = = = = ] время расчета: 0:00:34.317590
# Все ок. Подключились!
# Загрузка завершена успешно
# Записываем данные в таблицу фактов Buying
#
# Все ок. Подключились!
# Скрипт запущен 2025-06-04 14:20:42.089867
# Данные добавлены в БД: mediascope_x5, таблица: nat_tv_buying
# Скрипт отработал 2025-06-04 14:20:42.164885
# Время выполнения задачи: 0:00:00.075018
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
#
# **************************************************
#
# -------------------- Забираем статистику по отчету Simple
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
#
# Ждем выполнения
# Расчет задач (13) [ = = = = ] время расчета: 0:00:23.845644
# Расчет завершен, получаем результат
# Собираем таблицу
# .............Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
#
# **************************************************
# Записываем данные в справочник объявлений TV_Index
#
# Все ок. Подключились!
# Скрипт запущен 2025-06-04 14:21:39.540293
# Данные добавлены в БД: mediascope_x5, таблица: nat_tv_ad_dict
# Скрипт отработал 2025-06-04 14:21:39.555934
# Время выполнения задачи: 0:00:00.015641
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# **************************************************
#
# Записываем данные в таблицу фактов Simple
#
# Все ок. Подключились!
# Скрипт запущен 2025-06-04 14:21:39.555934
# Данные добавлены в БД: mediascope_x5, таблица: nat_tv_simple
# Скрипт отработал 2025-06-04 14:21:40.345965
# Время выполнения задачи: 0:00:00.790031
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# **************************************************
#
#
# ==========Загружаем 2025-05-24. Отправляем задания на расчет
#
# -------------------- Забираем статистику по отчету Buying
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Расчет задачи (id: 4bad02a1-6dba-4d02-98a0-09d9b75dee2b) [= = = = = = = = ] время расчета: 0:00:25.242206
# Все ок. Подключились!
# Загрузка завершена успешно
# Записываем данные в таблицу фактов Buying
#
# Все ок. Подключились!
# Скрипт запущен 2025-06-04 14:22:11.606982
# Данные добавлены в БД: mediascope_x5, таблица: nat_tv_buying
# Скрипт отработал 2025-06-04 14:22:11.690083
# Время выполнения задачи: 0:00:00.083101
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
#
# **************************************************
#
# -------------------- Забираем статистику по отчету Simple
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
#
# Ждем выполнения
# Расчет задач (13) [ = = = = = ] время расчета: 0:00:29.852215
# Расчет завершен, получаем результат
# Собираем таблицу
# .............Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
#
# **************************************************
# Записываем данные в справочник объявлений TV_Index
#
# Все ок. Подключились!
# Скрипт запущен 2025-06-04 14:23:14.833094
# Данные добавлены в БД: mediascope_x5, таблица: nat_tv_ad_dict
# Скрипт отработал 2025-06-04 14:23:14.845094
# Время выполнения задачи: 0:00:00.012000
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# **************************************************
#
# Записываем данные в таблицу фактов Simple
#
# Все ок. Подключились!
# Скрипт запущен 2025-06-04 14:23:14.850093
# Данные добавлены в БД: mediascope_x5, таблица: nat_tv_simple
# Скрипт отработал 2025-06-04 14:23:15.579378
# Время выполнения задачи: 0:00:00.729285
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# **************************************************
#
#
# ==========Загружаем 2025-05-25. Отправляем задания на расчет
#
# -------------------- Забираем статистику по отчету Buying
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Расчет задачи (id: 3bc18646-4e1a-41f7-8c4d-e2d26cb81207) [= = = = = = = = ] время расчета: 0:00:25.424654
# Все ок. Подключились!
# Загрузка завершена успешно
# Записываем данные в таблицу фактов Buying
#
# Все ок. Подключились!
# Скрипт запущен 2025-06-04 14:23:46.025527
# Данные добавлены в БД: mediascope_x5, таблица: nat_tv_buying
# Скрипт отработал 2025-06-04 14:23:46.093897
# Время выполнения задачи: 0:00:00.068370
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
#
# **************************************************
#
# -------------------- Забираем статистику по отчету Simple
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
#
# Ждем выполнения
# Расчет задач (13) [ = = = = = ] время расчета: 0:00:29.755734
# Расчет завершен, получаем результат
# Собираем таблицу
# .............Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
#
# **************************************************
# Записываем данные в справочник объявлений TV_Index
#
# Все ок. Подключились!
# Скрипт запущен 2025-06-04 14:24:49.382428
# Данные добавлены в БД: mediascope_x5, таблица: nat_tv_ad_dict
# Скрипт отработал 2025-06-04 14:24:49.395428
# Время выполнения задачи: 0:00:00.013000
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# **************************************************
#
# Записываем данные в таблицу фактов Simple
#
# Все ок. Подключились!
# Скрипт запущен 2025-06-04 14:24:49.401429
# Данные добавлены в БД: mediascope_x5, таблица: nat_tv_simple
# Скрипт отработал 2025-06-04 14:24:50.086650
# Время выполнения задачи: 0:00:00.685221
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# **************************************************
#
#
# ==========Загружаем 2025-05-26. Отправляем задания на расчет
#
# -------------------- Забираем статистику по отчету Buying
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Расчет задачи (id: 0aba11e6-70a7-4909-b363-65423b9c5c3f) [= = = = = = = = = ] время расчета: 0:00:28.251309
# Все ок. Подключились!
# Загрузка завершена успешно
# Записываем данные в таблицу фактов Buying
#
# Все ок. Подключились!
# Скрипт запущен 2025-06-04 14:25:24.177585
# Данные добавлены в БД: mediascope_x5, таблица: nat_tv_buying
# Скрипт отработал 2025-06-04 14:25:24.262871
# Время выполнения задачи: 0:00:00.085286
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
#
# **************************************************
#
# -------------------- Забираем статистику по отчету Simple
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
#
# Ждем выполнения
# Расчет задач (13) [ = = = = = ] время расчета: 0:00:29.768234
# Расчет завершен, получаем результат
# Собираем таблицу
# .............Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
#
# **************************************************
# Записываем данные в справочник объявлений TV_Index
#
# Все ок. Подключились!
# Скрипт запущен 2025-06-04 14:26:29.250454
# Данные добавлены в БД: mediascope_x5, таблица: nat_tv_ad_dict
# Скрипт отработал 2025-06-04 14:26:29.262000
# Время выполнения задачи: 0:00:00.011546
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# **************************************************
#
# Записываем данные в таблицу фактов Simple
#
# Все ок. Подключились!
# Скрипт запущен 2025-06-04 14:26:29.267998
# Данные добавлены в БД: mediascope_x5, таблица: nat_tv_simple
# Скрипт отработал 2025-06-04 14:26:29.960840
# Время выполнения задачи: 0:00:00.692842
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# **************************************************
#
#
# ==========Загружаем 2025-05-27. Отправляем задания на расчет
#
# -------------------- Забираем статистику по отчету Buying
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Расчет задачи (id: 834b1598-224e-454f-b888-e1c6db179966) [= = = = = = = = = ] время расчета: 0:00:28.266524
# Все ок. Подключились!
# Загрузка завершена успешно
# Записываем данные в таблицу фактов Buying
#
# Все ок. Подключились!
# Скрипт запущен 2025-06-04 14:27:04.424938
# Данные добавлены в БД: mediascope_x5, таблица: nat_tv_buying
# Скрипт отработал 2025-06-04 14:27:04.490445
# Время выполнения задачи: 0:00:00.065507
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
#
# **************************************************
#
# -------------------- Забираем статистику по отчету Simple
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
#
# Ждем выполнения
# Расчет задач (13) [ = = = = ] время расчета: 0:00:23.810511
# Расчет завершен, получаем результат
# Собираем таблицу
# .............Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
#
# **************************************************
# Записываем данные в справочник объявлений TV_Index
#
# Все ок. Подключились!
# Скрипт запущен 2025-06-04 14:28:02.451938
# Данные добавлены в БД: mediascope_x5, таблица: nat_tv_ad_dict
# Скрипт отработал 2025-06-04 14:28:02.473542
# Время выполнения задачи: 0:00:00.021604
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# **************************************************
#
# Записываем данные в таблицу фактов Simple
#
# Все ок. Подключились!
# Скрипт запущен 2025-06-04 14:28:02.479545
# Данные добавлены в БД: mediascope_x5, таблица: nat_tv_simple
# Скрипт отработал 2025-06-04 14:28:03.026971
# Время выполнения задачи: 0:00:00.547426
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# **************************************************
#
#
# ==========Загружаем 2025-05-28. Отправляем задания на расчет
#
# -------------------- Забираем статистику по отчету Buying
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Расчет задачи (id: 924440b5-51ef-4128-bcd6-b3dd1ecb3c67) [= = = = = = = = = ] время расчета: 0:00:28.258918
# Все ок. Подключились!
# Загрузка завершена успешно
# Записываем данные в таблицу фактов Buying
#
# Все ок. Подключились!
# Скрипт запущен 2025-06-04 14:28:37.657522
# Данные добавлены в БД: mediascope_x5, таблица: nat_tv_buying
# Скрипт отработал 2025-06-04 14:28:37.707521
# Время выполнения задачи: 0:00:00.049999
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
#
# **************************************************
#
# -------------------- Забираем статистику по отчету Simple
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
#
# Ждем выполнения
# Расчет задач (13) [ = = = ] время расчета: 0:00:17.868297
# Расчет завершен, получаем результат
# Собираем таблицу
# .............Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
#
# **************************************************
# Записываем данные в справочник объявлений TV_Index
#
# Все ок. Подключились!
# Скрипт запущен 2025-06-04 14:29:30.222507
# Данные добавлены в БД: mediascope_x5, таблица: nat_tv_ad_dict
# Скрипт отработал 2025-06-04 14:29:30.247055
# Время выполнения задачи: 0:00:00.024548
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# **************************************************
#
# Записываем данные в таблицу фактов Simple
#
# Все ок. Подключились!
# Скрипт запущен 2025-06-04 14:29:30.261061
# Данные добавлены в БД: mediascope_x5, таблица: nat_tv_simple
# Скрипт отработал 2025-06-04 14:29:30.925808
# Время выполнения задачи: 0:00:00.664747
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# **************************************************
#
#
# ==========Загружаем 2025-05-29. Отправляем задания на расчет
#
# -------------------- Забираем статистику по отчету Buying
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Расчет задачи (id: 85ca53c9-afb8-4de0-ac31-e6f8137cba92) [= = = = = = = = ] время расчета: 0:00:25.259300
# Все ок. Подключились!
# Загрузка завершена успешно
# Записываем данные в таблицу фактов Buying
#
# Все ок. Подключились!
# Скрипт запущен 2025-06-04 14:30:03.089257
# Данные добавлены в БД: mediascope_x5, таблица: nat_tv_buying
# Скрипт отработал 2025-06-04 14:30:03.176130
# Время выполнения задачи: 0:00:00.086873
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
#
# **************************************************
#
# -------------------- Забираем статистику по отчету Simple
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
#
# Ждем выполнения
# Расчет задач (13) [ = = = = = ] время расчета: 0:00:29.762766
# Расчет завершен, получаем результат
# Собираем таблицу
# .............Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
#
# **************************************************
# Записываем данные в справочник объявлений TV_Index
#
# Все ок. Подключились!
# Скрипт запущен 2025-06-04 14:31:07.970377
# Данные добавлены в БД: mediascope_x5, таблица: nat_tv_ad_dict
# Скрипт отработал 2025-06-04 14:31:07.991378
# Время выполнения задачи: 0:00:00.021001
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# **************************************************
#
# Записываем данные в таблицу фактов Simple
#
# Все ок. Подключились!
# Скрипт запущен 2025-06-04 14:31:07.998377
# Данные добавлены в БД: mediascope_x5, таблица: nat_tv_simple
# Скрипт отработал 2025-06-04 14:31:08.903468
# Время выполнения задачи: 0:00:00.905091
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# **************************************************
#
#
# ==========Загружаем 2025-05-30. Отправляем задания на расчет
#
# -------------------- Забираем статистику по отчету Buying
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Расчет задачи (id: c9ceec7b-1bef-42f8-a953-e592386f2986) [= = = = = = = = = ] время расчета: 0:00:28.269757
# Все ок. Подключились!
# Загрузка завершена успешно
# Записываем данные в таблицу фактов Buying
#
# Все ок. Подключились!
# Скрипт запущен 2025-06-04 14:31:43.122404
# Данные добавлены в БД: mediascope_x5, таблица: nat_tv_buying
# Скрипт отработал 2025-06-04 14:31:43.201444
# Время выполнения задачи: 0:00:00.079040
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
#
# **************************************************
#
# -------------------- Забираем статистику по отчету Simple
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
#
# Ждем выполнения
# Расчет задач (13) [ = = = ] время расчета: 0:00:17.845208
# Расчет завершен, получаем результат
# Собираем таблицу
# .............Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
#
# **************************************************
# Записываем данные в справочник объявлений TV_Index
#
# Все ок. Подключились!
# Скрипт запущен 2025-06-04 14:32:36.231178
# Данные добавлены в БД: mediascope_x5, таблица: nat_tv_ad_dict
# Скрипт отработал 2025-06-04 14:32:36.251790
# Время выполнения задачи: 0:00:00.020612
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# **************************************************
#
# Записываем данные в таблицу фактов Simple
#
# Все ок. Подключились!
# Скрипт запущен 2025-06-04 14:32:36.258788
# Данные добавлены в БД: mediascope_x5, таблица: nat_tv_simple
# Скрипт отработал 2025-06-04 14:32:37.005670
# Время выполнения задачи: 0:00:00.746882
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# **************************************************
#
#
# ==========Загружаем 2025-05-31. Отправляем задания на расчет
#
# -------------------- Забираем статистику по отчету Buying
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Расчет задачи (id: 2cba5f5f-965b-430f-97d9-d5c864493735) [= = = = = = = = = = = ] время расчета: 0:00:34.340823
# Все ок. Подключились!
# Загрузка завершена успешно
# Записываем данные в таблицу фактов Buying
#
# Все ок. Подключились!
# Скрипт запущен 2025-06-04 14:33:18.185532
# Данные добавлены в БД: mediascope_x5, таблица: nat_tv_buying
# Скрипт отработал 2025-06-04 14:33:18.267652
# Время выполнения задачи: 0:00:00.082120
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
#
# **************************************************
#
# -------------------- Забираем статистику по отчету Simple
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
#
# Ждем выполнения
# Расчет задач (13) [ = = = ] время расчета: 0:00:17.874251
# Расчет завершен, получаем результат
# Собираем таблицу
# .............Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
#
# **************************************************
# Записываем данные в справочник объявлений TV_Index
#
# Все ок. Подключились!
# Скрипт запущен 2025-06-04 14:34:10.939805
# Данные добавлены в БД: mediascope_x5, таблица: nat_tv_ad_dict
# Скрипт отработал 2025-06-04 14:34:10.963805
# Время выполнения задачи: 0:00:00.024000
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# **************************************************
#
# Записываем данные в таблицу фактов Simple
#
# Все ок. Подключились!
# Скрипт запущен 2025-06-04 14:34:10.970806
# Данные добавлены в БД: mediascope_x5, таблица: nat_tv_simple
# Скрипт отработал 2025-06-04 14:34:11.626436
# Время выполнения задачи: 0:00:00.655630
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# **************************************************
#
#
# ==========Загружаем 2025-06-01. Отправляем задания на расчет
#
# -------------------- Забираем статистику по отчету Buying
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Расчет задачи (id: fb6c8f11-8eac-40af-8281-46653767dcf4) [= = = = = = = = = = = ] время расчета: 0:00:34.321822
# Все ок. Подключились!
# Загрузка завершена успешно
# Записываем данные в таблицу фактов Buying
#
# Все ок. Подключились!
# Скрипт запущен 2025-06-04 14:34:51.913631
# Данные добавлены в БД: mediascope_x5, таблица: nat_tv_buying
# Скрипт отработал 2025-06-04 14:34:52.029060
# Время выполнения задачи: 0:00:00.115429
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
#
# **************************************************
#
# -------------------- Забираем статистику по отчету Simple
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
#
# Ждем выполнения
# Расчет задач (13) [ = = = = = = ] время расчета: 0:00:35.683209
# Расчет завершен, получаем результат
# Собираем таблицу
# .............Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
#
# **************************************************
# Записываем данные в справочник объявлений TV_Index
#
# Все ок. Подключились!
# Скрипт запущен 2025-06-04 14:36:04.611710
# Данные добавлены в БД: mediascope_x5, таблица: nat_tv_ad_dict
# Скрипт отработал 2025-06-04 14:36:04.650970
# Время выполнения задачи: 0:00:00.039260
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# **************************************************
#
# Записываем данные в таблицу фактов Simple
#
# Все ок. Подключились!
# Скрипт запущен 2025-06-04 14:36:04.660368
# Данные добавлены в БД: mediascope_x5, таблица: nat_tv_simple
# Скрипт отработал 2025-06-04 14:36:05.603989
# Время выполнения задачи: 0:00:00.943621
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# **************************************************
#
# **************************************************
# Время окончания работы скрипта 2025-06-04 14:36:05.603989
# Период загрузки 2025-05-18 - 2025-06-01. Общее время работы скрипта: 0:24:23.403931
# **************************************************

# %%
# ПОСЛЕ загрузки данных Обновляем все справочники из ТВ Индекс
update_tv_index_dicts()
sleep(10)
# Обновляем основной справочник объявлений
update_nat_tv_ad_dict()
# Out:
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Запрошены записи: 0 - 11
# Всего найдено записей: 11
#
# Все ок. Подключились!
# Скрипт запущен 2025-06-04 14:56:11.909494
# Данные добавлены в БД: mediascope_x5, таблица: tv_index_brand_list_dict
# Скрипт отработал 2025-06-04 14:56:11.923869
# Время выполнения задачи: 0:00:00.014375
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Запрошены записи: 0 - 0
# Всего найдено записей: 0
#
# Запрошены записи: 0 - 13
# Всего найдено записей: 13
#
# Все ок. Подключились!
# Скрипт запущен 2025-06-04 14:56:12.068069
# Данные добавлены в БД: mediascope_x5, таблица: tv_index_subbrand_list_dict
# Скрипт отработал 2025-06-04 14:56:12.080114
# Время выполнения задачи: 0:00:00.012045
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Запрошены записи: 0 - 17
# Всего найдено записей: 17
#
# Все ок. Подключились!
# Скрипт запущен 2025-06-04 14:56:12.185077
# Данные добавлены в БД: mediascope_x5, таблица: tv_index_model_list_dict
# Скрипт отработал 2025-06-04 14:56:12.201110
# Время выполнения задачи: 0:00:00.016033
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Запрошены записи: 0 - 5
# Всего найдено записей: 5
#
# Все ок. Подключились!
# Скрипт запущен 2025-06-04 14:56:12.273471
# Данные добавлены в БД: mediascope_x5, таблица: tv_index_article_list2_dict
# Скрипт отработал 2025-06-04 14:56:12.287137
# Время выполнения задачи: 0:00:00.013666
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Запрошены записи: 0 - 8
# Всего найдено записей: 8
#
# Все ок. Подключились!
# Скрипт запущен 2025-06-04 14:56:12.377944
# Данные добавлены в БД: mediascope_x5, таблица: tv_index_article_list3_dict
# Скрипт отработал 2025-06-04 14:56:12.391409
# Время выполнения задачи: 0:00:00.013465
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Запрошены записи: 0 - 14
# Всего найдено записей: 14
#
# Все ок. Подключились!
# Скрипт запущен 2025-06-04 14:56:12.498483
# Данные добавлены в БД: mediascope_x5, таблица: tv_index_article_list4_dict
# Скрипт отработал 2025-06-04 14:56:12.513892
# Время выполнения задачи: 0:00:00.015409
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Таблица: nat_tv_ad_dict успешно удалена в БД: mediascope_x5
# ##########
# Все ок. Подключились!
# Пустая таблица nat_tv_ad_dict успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Скрипт запущен 2025-06-04 14:56:37.086317
# Данные добавлены в БД: mediascope_x5, таблица: nat_tv_ad_dict
# Скрипт отработал 2025-06-04 14:56:37.704033
# Время выполнения задачи: 0:00:00.617716
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################

# %%
# Обновляем справочники медиа инвестиций
for media_type, media_type_long in config.media_type_dict.items():
    # здесь загружаем недостающие ИД
    update_media_ads_dict(media_type)
    # здесь обновляем кастомные поля(флаг чистки, категория и тд) в справочнике объявлений
    update_ad_dict_items(media_type)
    update_another_dicts(media_type)
    update_list_dicts(media_type)
# Out:
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# **************************************************
# Новых ИД НЕТ для загрузки в таблицу adex_ad_dict_list_tv
# **************************************************
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Таблица: adex_ad_dict_list_tv успешно удалена в БД: mediascope_x5
# ##########
# Все ок. Подключились!
# Пустая таблица adex_ad_dict_list_tv успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Скрипт запущен 2025-06-04 14:56:58.170967
# Данные добавлены в БД: mediascope_x5, таблица: adex_ad_dict_list_tv
# Скрипт отработал 2025-06-04 14:57:00.746318
# Время выполнения задачи: 0:00:02.575351
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# **************************************************
# Новых ИД НЕТ для загрузки в таблицу adex_audio_slogan_dict_tv
# **************************************************
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# **************************************************
# Новых ИД НЕТ для загрузки в таблицу adex_video_slogan_dict_tv
# **************************************************
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# **************************************************
# Новых ИД НЕТ для загрузки в таблицу adex_advertiser_list_dict
# **************************************************
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# **************************************************
# Новых ИД НЕТ для загрузки в таблицу adex_brand_list_dict
# **************************************************
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# **************************************************
# Новых ИД НЕТ для загрузки в таблицу adex_subbrand_list_dict
# **************************************************
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# **************************************************
# Новых ИД НЕТ для загрузки в таблицу adex_model_list_dict
# **************************************************
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# **************************************************
# Новых ИД НЕТ для загрузки в таблицу adex_article_list2_dict
# **************************************************
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# **************************************************
# Новых ИД НЕТ для загрузки в таблицу adex_article_list3_dict
# **************************************************
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# **************************************************
# Новых ИД НЕТ для загрузки в таблицу adex_article_list4_dict
# **************************************************
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# **************************************************
# Новых ИД НЕТ для загрузки в таблицу adex_ad_dict_list_radio
# **************************************************
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Таблица: adex_ad_dict_list_radio успешно удалена в БД: mediascope_x5
# ##########
# Все ок. Подключились!
# Пустая таблица adex_ad_dict_list_radio успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Скрипт запущен 2025-06-04 14:57:15.357722
# Данные добавлены в БД: mediascope_x5, таблица: adex_ad_dict_list_radio
# Скрипт отработал 2025-06-04 14:57:15.655183
# Время выполнения задачи: 0:00:00.297461
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# **************************************************
# Новых ИД НЕТ для загрузки в таблицу adex_advertiser_list_dict
# **************************************************
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# **************************************************
# Новых ИД НЕТ для загрузки в таблицу adex_brand_list_dict
# **************************************************
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# **************************************************
# Новых ИД НЕТ для загрузки в таблицу adex_subbrand_list_dict
# **************************************************
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# **************************************************
# Новых ИД НЕТ для загрузки в таблицу adex_model_list_dict
# **************************************************
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# **************************************************
# Новых ИД НЕТ для загрузки в таблицу adex_article_list2_dict
# **************************************************
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# **************************************************
# Новых ИД НЕТ для загрузки в таблицу adex_article_list3_dict
# **************************************************
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# **************************************************
# Новых ИД НЕТ для загрузки в таблицу adex_article_list4_dict
# **************************************************
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# **************************************************
# Новых ИД НЕТ для загрузки в таблицу adex_ad_dict_list_outdoor
# **************************************************
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Таблица: adex_ad_dict_list_outdoor успешно удалена в БД: mediascope_x5
# ##########
# Все ок. Подключились!
# Пустая таблица adex_ad_dict_list_outdoor успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Скрипт запущен 2025-06-04 14:57:23.678237
# Данные добавлены в БД: mediascope_x5, таблица: adex_ad_dict_list_outdoor
# Скрипт отработал 2025-06-04 14:57:24.556392
# Время выполнения задачи: 0:00:00.878155
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# **************************************************
# Новых ИД НЕТ для загрузки в таблицу adex_advertiser_list_dict
# **************************************************
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# **************************************************
# Новых ИД НЕТ для загрузки в таблицу adex_brand_list_dict
# **************************************************
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# **************************************************
# Новых ИД НЕТ для загрузки в таблицу adex_subbrand_list_dict
# **************************************************
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# **************************************************
# Новых ИД НЕТ для загрузки в таблицу adex_model_list_dict
# **************************************************
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# **************************************************
# Новых ИД НЕТ для загрузки в таблицу adex_article_list2_dict
# **************************************************
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# **************************************************
# Новых ИД НЕТ для загрузки в таблицу adex_article_list3_dict
# **************************************************
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# **************************************************
# Новых ИД НЕТ для загрузки в таблицу adex_article_list4_dict
# **************************************************
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# **************************************************
# Новых ИД НЕТ для загрузки в таблицу adex_ad_dict_list_press
# **************************************************
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Таблица: adex_ad_dict_list_press успешно удалена в БД: mediascope_x5
# ##########
# Все ок. Подключились!
# Пустая таблица adex_ad_dict_list_press успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Скрипт запущен 2025-06-04 14:57:37.293470
# Данные добавлены в БД: mediascope_x5, таблица: adex_ad_dict_list_press
# Скрипт отработал 2025-06-04 14:57:37.335339
# Время выполнения задачи: 0:00:00.041869
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# **************************************************
# Новых ИД НЕТ для загрузки в таблицу adex_advertiser_list_dict
# **************************************************
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# **************************************************
# Новых ИД НЕТ для загрузки в таблицу adex_brand_list_dict
# **************************************************
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# **************************************************
# Новых ИД НЕТ для загрузки в таблицу adex_subbrand_list_dict
# **************************************************
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# **************************************************
# Новых ИД НЕТ для загрузки в таблицу adex_model_list_dict
# **************************************************
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# **************************************************
# Новых ИД НЕТ для загрузки в таблицу adex_article_list2_dict
# **************************************************
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# **************************************************
# Новых ИД НЕТ для загрузки в таблицу adex_article_list3_dict
# **************************************************
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# **************************************************
# Новых ИД НЕТ для загрузки в таблицу adex_article_list4_dict
# **************************************************

# %%
# ПОСЛЕ загрузки данных Обновляем все справочники из ТВ Индекс
update_tv_index_dicts()
sleep(10)
# Обновляем основной справочник объявлений
update_nat_tv_ad_dict()
# Out:
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Таблица: nat_tv_ad_dict успешно удалена в БД: mediascope_x5
# ##########
# Все ок. Подключились!
# Пустая таблица nat_tv_ad_dict успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Скрипт запущен 2025-06-04 15:00:34.439882
# Данные добавлены в БД: mediascope_x5, таблица: nat_tv_ad_dict
# Скрипт отработал 2025-06-04 15:00:35.041489
# Время выполнения задачи: 0:00:00.601607
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################

# %%
# загружаем в гугл докс Чистка список объяалений с флагом=2

query = query_for_google(report='ratings')
worksheet = config_tv_index.google_new_ads_nat_tv['worksheet']

append_ads_to_google(query=query, worksheet=worksheet)
# Out:
# Все ок. Подключились!
# Загрузка завершена успешно
# Connection established successfully...
# DataFrame exported successfully...

# %%
# # Может возникнуть необходимость перезаписать кастомные поля в таблицах ТВ индекс
# # например - пересмотрели размер дисконта / изменили правила опеределения одной из кастомных колонок и тд.
# # В этом случае забираем из нашей БД из каждой таблицы расходов колонки, которые мы взяли из ТВ индекс
# # И пропускаем по тем же шагам обработки, которые применялись в первоначальной загрузке
# # По итогу - удаляем существующую таблицу в БД и на ее место записываем таблицу с новуми данными


# update_nat_tv_fact(report='simple')
# sleep(20)
# update_nat_tv_fact(report='buying')
